# %%
# Install required packages.
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-geometric

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from torchsummary import summary

from torch_geometric.datasets import ModelNet, ShapeNet
from torch_geometric.transforms import Compose, FixedPoints, SamplePoints, NormalizeScale
from torch_geometric.data import DataLoader

import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import time

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    
torch.__version__, device
# Out:
# ('1.9.0+cu102', device(type='cuda'))

# %%
def visualize_mesh(pos, face):
    # from the tutorial https://colab.research.google.com/drive/1D45E5bUK3gQ40YpZo65ozs7hg5l-eo_U?usp=sharing#scrollTo=SvsEAR28LUI7
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.axes.xaxis.set_ticklabels([])
    ax.axes.yaxis.set_ticklabels([])
    ax.axes.zaxis.set_ticklabels([])
    ax.plot_trisurf(pos[:, 0], pos[:, 1], pos[:, 2], triangles=face.t(), antialiased=False)
    plt.show()


def visualize_points(points, ax=None, show_grid=False, is_shapenet=False):
    fig = plt.figure()
    if ax is None:
        ax = fig.gca(projection='3d')
    ax.patch.set_alpha(0)
    ax.view_init(elev=10., azim=240.)
    ax.grid(show_grid)
    if is_shapenet:
      ax.scatter(points[:,0], points[:,2], points[:,1], c=points[:,2], cmap='plasma', s=10)
    else:
      ax.scatter(points[:,0], points[:,1], points[:,2], c=points[:,1], cmap='plasma', s=10)
    

def visualize_real_and_generated_samples(samples, show_grid=False, is_shapenet=False):
    fig = plt.figure(figsize=(16, 8))
    for i, sample in enumerate(samples):
        ax = fig.add_subplot(1, 2, i+1, projection='3d')
        visualize_points(sample, ax, show_grid, is_shapenet)

# %%
# import os
# import os.path as osp
# import shutil
# import glob

# import torch
# from torch_geometric.data import InMemoryDataset, download_url, extract_zip
# from torch_geometric.io import read_off

# class CustomModelNet(InMemoryDataset):
#     r"""The ModelNet10/40 datasets from the `"3D ShapeNets: A Deep
#     Representation for Volumetric Shapes"
#     <https://people.csail.mit.edu/khosla/papers/cvpr2015_wu.pdf>`_ paper,
#     containing CAD models of 10 and 40 categories, respectively.

#     .. note::

#         Data objects hold mesh faces instead of edge indices.
#         To convert the mesh to a graph, use the
#         :obj:`torch_geometric.transforms.FaceToEdge` as :obj:`pre_transform`.
#         To convert the mesh to a point cloud, use the
#         :obj:`torch_geometric.transforms.SamplePoints` as :obj:`transform` to
#         sample a fixed number of points on the mesh faces according to their
#         face area.

#     Args:
#         root (string): Root directory where the dataset should be saved.
#         name (string, optional): The name of the dataset (:obj:`"10"` for
#             ModelNet10, :obj:`"40"` for ModelNet40). (default: :obj:`"10"`)
#         train (bool, optional): If :obj:`True`, loads the training dataset,
#             otherwise the test dataset. (default: :obj:`True`)
#         transform (callable, optional): A function/transform that takes in an
#             :obj:`torch_geometric.data.Data` object and returns a transformed
#             version. The data object will be transformed before every access.
#             (default: :obj:`None`)
#         pre_transform (callable, optional): A function/transform that takes in
#             an :obj:`torch_geometric.data.Data` object and returns a
#             transformed version. The data object will be transformed before
#             being saved to disk. (default: :obj:`None`)
#         pre_filter (callable, optional): A function that takes in an
#             :obj:`torch_geometric.data.Data` object and returns a boolean
#             value, indicating whether the data object should be included in the
#             final dataset. (default: :obj:`None`)
#     """

#     urls = {
#         '10':
#         'http://vision.princeton.edu/projects/2014/3DShapeNets/ModelNet10.zip',
#         '40': 'http://modelnet.cs.princeton.edu/ModelNet40.zip'
#     }

#     def __init__(self, root, name='10', train=True, transform=None,
#                  pre_transform=None, pre_filter=None, pre_filter_target=None):
#         assert name in ['10', '40']
#         self.name = name
#         self.pre_filter_target = pre_filter_target
#         super(CustomModelNet, self).__init__(root, transform, pre_transform,
#                                        pre_filter)
#         path = self.processed_paths[0] if train else self.processed_paths[1]
#         self.data, self.slices = torch.load(path)

#     @property
#     def raw_file_names(self):
#         return [
#             'bathtub', 'bed', 'chair', 'desk', 'dresser', 'monitor',
#             'night_stand', 'sofa', 'table', 'toilet'
#         ]

#     @property
#     def processed_file_names(self):
#         return ['training.pt', 'test.pt']

#     def download(self):
#         path = download_url(self.urls[self.name], self.root)
#         extract_zip(path, self.root)
#         os.unlink(path)
#         folder = osp.join(self.root, 'ModelNet{}'.format(self.name))
#         shutil.rmtree(self.raw_dir)
#         os.rename(folder, self.raw_dir)

#         # Delete osx metadata generated during compression of ModelNet10
#         metadata_folder = osp.join(self.root, '__MACOSX')
#         if osp.exists(metadata_folder):
#             shutil.rmtree(metadata_folder)

#     def process(self):
#         torch.save(self.process_set('train'), self.processed_paths[0])
#         torch.save(self.process_set('test'), self.processed_paths[1])

#     def process_set(self, dataset):
#         categories = glob.glob(osp.join(self.raw_dir, '*', ''))
#         categories = sorted([x.split(os.sep)[-2] for x in categories])

#         data_list = []
#         for target, category in enumerate(categories):
#             if self.pre_filter_target is not None and not self.pre_filter_target(target):
#                 continue
            
#             folder = osp.join(self.raw_dir, category, dataset)
#             paths = glob.glob('{}/{}_*.off'.format(folder, category))
                            
#             for path in paths:
#                 data = read_off(path)
#                 data.y = torch.tensor([target])
#                 data_list.append(data)

#         if self.pre_filter is not None:
#             data_list = [d for d in data_list if self.pre_filter(d)]

#         if self.pre_transform is not None:
#             data_list = [self.pre_transform(d) for d in data_list]

#         return self.collate(data_list)

#     def __repr__(self):
#         return '{}{}({})'.format(self.__class__.__name__, self.name, len(self))

# %% [markdown]
# ## Process the data (ShapeNet or ModelNet)

# %%
shape_name = 'Lamp'

# %%
#dataset = ModelNet(root='E:\data\modelnet40_data', name='40')
#shape_label = 0
#dataset = CustomModelNet(root='.', name='40', pre_filter_target=lambda y: y == shape_label)


dataset = ShapeNet(root='.', categories=shape_name)


print(dataset)

data = dataset[0]
print(data)
# print(type(data.face), data.face)
# visualize_mesh(data.pos, data.face) # for ModelNet
visualize_points(data.pos, is_shapenet=True)


data = dataset[4]
print(data)
# visualize_mesh(data.pos, data.face) # for ModelNet
visualize_points(data.pos, is_shapenet=True)
# Out:
# Downloading https://shapenet.cs.stanford.edu/media/shapenetcore_partanno_segmentation_benchmark_v0_normal.zip
# Extracting ./shapenetcore_partanno_segmentation_benchmark_v0_normal.zip
# Processing...
# Done!
# ShapeNet(1261, categories=['Lamp'])
# Data(category=[1], pos=[2663, 3], x=[2663, 3], y=[2663])
# Data(category=[1], pos=[2477, 3], x=[2477, 3], y=[2477])

# %% [markdown]
# ### Normalize the position scale (for ModelNet) and sample and plot points

# %%
torch.manual_seed(11)

n_points = 2048 # number of points to sample
dataset.transform = FixedPoints(num=n_points) # samples points from a point cloud

# for ModelNet:
# SamplePoints samples points from a mesh
# dataset.transform = Compose([SamplePoints(num=n_points), NormalizeScale()])

# %%
# sanity check:
data = dataset[4]
print(data)
visualize_points(data.pos, is_shapenet=True)
# Out:
# Data(category=[1], pos=[2048, 3], x=[2048, 3], y=[2048])

# %% [markdown]
# ### Collect the data for a single class

# %%
# shape_label = 0
# single_class_data = dataset[dataset.data.y==shape_label]
single_class_data = dataset
n_shapes = len(single_class_data)
n_shapes
# Out:
# 1261

# %% [markdown]
# ## Raw GAN (r-GAN)
#
# (See https://arxiv.org/pdf/1707.02392.pdf)
#
# **Generator**
#
# Input  128 --->  Linear 64 + ReLU  ---> Linear 128 + ReLU ---> Linear 512 + ReLU --->  Linear 1024 + ReLU  --->  Linear 2048*3
#
# <br></br>
#
# **Discriminator**
#
# Input 2048x3 --->
#
# ENCODER
#
# Conv1D (2048, 64, kernel_size=1)   + LeakyReLU  --->
# Conv1D (64, 128, kernel_size=1)    + LeakyReLU --->
# Conv1D (128, 256, kernel_size=1)   + LeakyReLU  --->
# Conv1D (256, 256, kernel_size=1)   + LeakyReLU  --->
# Conv1D (256, 512, kernel_size=1)   + LeakyReLU  --->
# (output.shape = (512, 3))
#
# --->
#
# DECODER
#
# --->  Linear(512, 128) + ReLU ---> Linear(128, 64) + ReLU --->
# --->  Linear(64, 1) + Sigmoid ---> Fake or Real

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Generator, self).__init__()
        
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64), nn.ReLU(True),
            nn.Linear(64, 128), nn.ReLU(True),
            nn.Linear(128, 512), nn.ReLU(True),
            nn.Linear(512, 1024), nn.ReLU(True),
            nn.Linear(1024, output_dim)
        )
        
    def forward(self, x):
        # reshape to batch_size x 3 x n_points
        samples = self.model(x).view(x.size(0), 3, -1)

        # TODO: try clipping the output to be in [-1, 1], e.g., by applying tanh
        # samples.clamp_(min=-1, max=1)

        return samples
    
    def init_params(self, layer):
        if type(layer) == nn.Linear:
            nn.init.xavier_uniform_(layer.weight.data)
            nn.init.zeros_(layer.bias.data)

# %%
# instantiate the r-GAN generator
raw_gan_gen_input_dim = 128
raw_gan_gen = Generator(raw_gan_gen_input_dim, n_points*3).to(device)

# initialize the parameters:
raw_gan_gen.apply(raw_gan_gen.init_params)

mu = 0.
sigma = 0.2

z = torch.FloatTensor(1, raw_gan_gen_input_dim).normal_(mu, sigma).to(device)

print(z.shape)
print(raw_gan_gen(z).shape)

summary(raw_gan_gen, (1, raw_gan_gen_input_dim))
# Out:
# torch.Size([1, 128])
# torch.Size([1, 3, 2048])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]           8,256
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3               [-1, 1, 128]           8,320
#               ReLU-4               [-1, 1, 128]               0
#             Linear-5               [-1, 1, 512]          66,048
#               ReLU-6               [-1, 1, 512]               0
#             Linear-7              [-1, 1, 1024]         525,312
#               ReLU-8              [-1, 1, 1024]               0
#             Linear-9              [-1, 1, 6144]       6,297,600
# ================================================================
# Total params: 6,905,536
# Trainable params: 6,905,536
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.07
# Params size (MB): 26.34
# Estimated Total Size (MB): 26.42
# ----------------------------------------------------------------

# %%
class Discriminator(nn.Module):
    def __init__(self, encoder_in_ch, encoder_out_ch):        
        super(Discriminator, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Conv1d(encoder_in_ch, 64, 1, 1), nn.LeakyReLU(0.2),
            nn.Conv1d(64, 128, 1, 1), nn.LeakyReLU(0.2),
            nn.Conv1d(128, 256, 1, 1), nn.LeakyReLU(0.2),
            nn.Conv1d(256, 256, 1, 1), nn.LeakyReLU(0.2),
            nn.Conv1d(256, encoder_out_ch, 1, 1), nn.LeakyReLU(0.2)
        )
        # outputs (batch_size x encoder_out_ch x n_points)
        # we then maxpool the output in the forward method, 
        # so the input to the decoder becomes (batch_size x encoder_out_ch)
        
        self.decoder = nn.Sequential(
            nn.Linear(encoder_out_ch, 128), nn.ReLU(True),
            nn.Linear(128, 64), nn.ReLU(True),
            nn.Linear(64, 1), nn.Sigmoid(),
        )
   

    def forward(self, x):
        x = self.encoder(x)
        x, _ = torch.max(x, dim=-1)
        x = self.decoder(x)
        return x
            
            
    def init_params(self, layer):
        if type(layer) == nn.Conv1d:
            nn.init.kaiming_uniform_(layer.weight.data)
            nn.init.zeros_(layer.bias.data)            
        if type(layer) == nn.Linear:
            nn.init.xavier_uniform_(layer.weight.data)
            nn.init.zeros_(layer.bias.data)

# %%
# instantiate the r-GAN discriminator:
raw_gan_dis_input_ch = 3
raw_gan_dis = Discriminator(raw_gan_dis_input_ch, 512).to(device)

# initialize the parameters:
raw_gan_dis.apply(raw_gan_dis.init_params)

# print the summary:
y = torch.ones((1, 3, 2048)).to(device)
print(y.shape)

pred = raw_gan_dis(y)
print(pred.shape)

summary(raw_gan_dis, (raw_gan_dis_input_ch, 2048))
# Out:
# torch.Size([1, 3, 2048])
# torch.Size([1, 1])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 64, 2048]             256
#          LeakyReLU-2             [-1, 64, 2048]               0
#             Conv1d-3            [-1, 128, 2048]           8,320
#          LeakyReLU-4            [-1, 128, 2048]               0
#             Conv1d-5            [-1, 256, 2048]          33,024
#          LeakyReLU-6            [-1, 256, 2048]               0
#             Conv1d-7            [-1, 256, 2048]          65,792
#          LeakyReLU-8            [-1, 256, 2048]               0
#             Conv1d-9            [-1, 512, 2048]         131,584
#         LeakyReLU-10            [-1, 512, 2048]               0
#            Linear-11                  [-1, 128]          65,664
#              ReLU-12                  [-1, 128]               0
#            Linear-13                   [-1, 64]           8,256
#              ReLU-14                   [-1, 64]               0
#            Linear-15                    [-1, 1]              65
#           Sigmoid-16                    [-1, 1]               0
# ================================================================
# Total params: 312,961
# Trainable params: 312,961
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 38.00
# Params size (MB): 1.19
# Estimated Total Size (MB): 39.22
# ----------------------------------------------------------------

# %% [markdown]
# ## Optimize the r-GAN

# %% [markdown]
# ### Optimization setup

# %%
# hyperparameters:
lr_gen = 1e-4
lr_dis = 1e-4
beta1 = 0.5
beta2 = 0.999

# two separate optimizers for the generator and discriminator:
optimizer_gen = optim.Adam(params=raw_gan_gen.parameters(), 
                           lr=lr_gen, 
                           betas=(beta1, beta2))

optimizer_dis = optim.Adam(params=raw_gan_dis.parameters(), 
                           lr=lr_dis, 
                           betas=(beta1, beta2))

# by supplying with the correct labels, we will make it 
# equivalent to using non-saturating heuristic for the generator
# and the standard binary cross-entropy for the discriminator
criterion = nn.BCELoss().to(device)
criterion_gen = criterion # nn.BCELoss().to(device)
criterion_dis = criterion # nn.BCELoss().to(device)

# %% [markdown]
# ### Create a dataloader for our single class dataset

# %%
batch_size = 50
dataloader = DataLoader(dataset=single_class_data, 
                        batch_size=batch_size, 
                        shuffle=True,
                        drop_last=True)

print('Batch size: ', batch_size)
print('Number of batches:', len(dataloader))
# Out:
# Batch size:  50
# Number of batches: 25

# %% [markdown]
# ### Training loop

# %%
epochs = 200
print_period = 10

losses_gen = []
losses_dis = []

for i in range(epochs):
    t0 = time.time()
    
    for batch_idx, batch_data in enumerate(dataloader):
        print(batch_idx, end='\r')
        batch_t0 = time.time()
        batch_size = batch_data.pos.shape[0] // n_points
        
        x = batch_data.pos.reshape(batch_size, n_points, 3).transpose(2, 1).to(device)
        
        # sample random vectors and generate samples from them:
        z = torch.FloatTensor(batch_size, raw_gan_gen_input_dim).normal_(mu, sigma).to(device)
        gen_samples = raw_gan_gen(z)
        
        # get the discriminator output for the two types of input:
        prob_x = raw_gan_dis(x)
        prob_gen_samples = raw_gan_dis(gen_samples)
        
        # the target probabilities:
        prob_real = torch.ones((batch_size, 1)).to(device)
        prob_fake = torch.zeros((batch_size, 1)).to(device)
        
        # the non-saturating heuristic loss for the generator:
        loss_gen = criterion_gen(prob_gen_samples, prob_real)
        
        # compute the gradient of the loss_gen wrt the generator parameters:
        optimizer_gen.zero_grad()
        loss_gen.backward(retain_graph=True)
        
        # update the generator parameters:
        optimizer_gen.step()
        losses_gen.append(loss_gen.item())

        # update the discrimiator parameters twice as rarely:
        # if batch_idx % 2 == 0:        
        # the usual (binary cross-entropy) loss for the discriminator:
        loss_dis_real_term = criterion_dis(prob_x, prob_real)
        loss_dis_fake_term = criterion_dis(raw_gan_dis(gen_samples.detach()), prob_fake)
        loss_dis = loss_dis_real_term + loss_dis_fake_term
        
        # compute the gradient and update the discriminator parameters:
        optimizer_dis.zero_grad()
        loss_dis.backward()
        optimizer_dis.step()
        losses_dis.append(loss_dis.item())
        
        if batch_idx % print_period == 0:
            print('ETA: %.5f, epoch: %d/%d, batch: %d/%d, loss_gen: %.3f, loss_dis: %.3f'
              % (time.time() - batch_t0, i+1, epochs, batch_idx, len(dataloader), torch.mean(torch.FloatTensor(losses_gen)), torch.mean(torch.FloatTensor(losses_dis)))
            )
            
    print('ETA: %.5f' % (time.time() - t0), end='\n\n')
# Out:
# ETA: 0.38402, epoch: 1/200, batch: 0/25, loss_gen: 0.695, loss_dis: 1.356
# ETA: 0.24614, epoch: 1/200, batch: 10/25, loss_gen: 0.604, loss_dis: 1.128
# ETA: 0.24585, epoch: 1/200, batch: 20/25, loss_gen: 0.580, loss_dis: 1.134
# ETA: 6.80223
#
# ETA: 0.24698, epoch: 2/200, batch: 0/25, loss_gen: 0.590, loss_dis: 1.152
# ETA: 0.24939, epoch: 2/200, batch: 10/25, loss_gen: 0.612, loss_dis: 1.197
# ETA: 0.25023, epoch: 2/200, batch: 20/25, loss_gen: 0.650, loss_dis: 1.208
# ETA: 6.59711
#
# ETA: 0.24905, epoch: 3/200, batch: 0/25, loss_gen: 0.668, loss_dis: 1.212
# ETA: 0.24859, epoch: 3/200, batch: 10/25, loss_gen: 0.702, loss_dis: 1.214
# ETA: 0.25135, epoch: 3/200, batch: 20/25, loss_gen: 0.728, loss_dis: 1.205
# ETA: 6.65011
#
# ETA: 0.25135, epoch: 4/200, batch: 0/25, loss_gen: 0.736, loss_dis: 1.205
# ETA: 0.25189, epoch: 4/200, batch: 10/25, loss_gen: 0.754, loss_dis: 1.195
# ETA: 0.24990, epoch: 4/200, batch: 20/25, loss_gen: 0.769, loss_dis: 1.185
# ETA: 6.69265
#
# ETA: 0.25527, epoch: 5/200, batch: 0/25, loss_gen: 0.775, loss_dis: 1.179
# ETA: 0.25148, epoch: 5/200, batch: 10/25, loss_gen: 0.782, loss_dis: 1.172
# ETA: 0.25417, epoch: 5/200, batch: 20/25, loss_gen: 0.791, loss_dis: 1.159
# ETA: 6.74423
#
# ETA: 0.25369, epoch: 6/200, batch: 0/25, loss_gen: 0.794, loss_dis: 1.155
# ETA: 0.25554, epoch: 6/200, batch: 10/25, loss_gen: 0.799, loss_dis: 1.144
# ETA: 0.25912, epoch: 6/200, batch: 20/25, loss_gen: 0.816, loss_dis: 1.123
# ETA: 6.77274
#
# ETA: 0.25538, epoch: 7/200, batch: 0/25, loss_gen: 0.819, loss_dis: 1.119
# ETA: 0.25886, epoch: 7/200, batch: 10/25, loss_gen: 0.821, loss_dis: 1.113
# ETA: 0.25556, epoch: 7/200, batch: 20/25, loss_gen: 0.832, loss_dis: 1.099
# ETA: 6.79332
#
# ETA: 0.25693, epoch: 8/200, batch: 0/25, loss_gen: 0.839, loss_dis: 1.092
# ETA: 0.26103, epoch: 8/200, batch: 10/25, loss_gen: 0.854, loss_dis: 1.076
# ETA: 0.26044, epoch: 8/200, batch: 20/25, loss_gen: 0.864, loss_dis: 1.063
# ETA: 6.83168
#
# ETA: 0.25839, epoch: 9/200, batch: 0/25, loss_gen: 0.868, loss_dis: 1.057
# ETA: 0.25926, epoch: 9/200, batch: 10/25, loss_gen: 0.881, loss_dis: 1.043
# ETA: 0.25972, epoch: 9/200, batch: 20/25, loss_gen: 0.900, loss_dis: 1.027
# ETA: 6.88545
#
# ETA: 0.25997, epoch: 10/200, batch: 0/25, loss_gen: 0.906, loss_dis: 1.019
# ETA: 0.26318, epoch: 10/200, batch: 10/25, loss_gen: 0.916, loss_dis: 1.004
# ETA: 0.26326, epoch: 10/200, batch: 20/25, loss_gen: 0.932, loss_dis: 0.987
# ETA: 6.94631
#
# ETA: 0.26740, epoch: 11/200, batch: 0/25, loss_gen: 0.944, loss_dis: 0.978
# ETA: 0.26351, epoch: 11/200, batch: 10/25, loss_gen: 0.960, loss_dis: 0.966
# ETA: 0.26821, epoch: 11/200, batch: 20/25, loss_gen: 0.977, loss_dis: 0.953
# ETA: 7.01023
#
# ETA: 0.26612, epoch: 12/200, batch: 0/25, loss_gen: 0.991, loss_dis: 0.944
# ETA: 0.26824, epoch: 12/200, batch: 10/25, loss_gen: 1.008, loss_dis: 0.932
# ETA: 0.26951, epoch: 12/200, batch: 20/25, loss_gen: 1.028, loss_dis: 0.917
# ETA: 7.08447
#
# ETA: 0.26872, epoch: 13/200, batch: 0/25, loss_gen: 1.039, loss_dis: 0.910
# ETA: 0.27111, epoch: 13/200, batch: 10/25, loss_gen: 1.056, loss_dis: 0.898
# ETA: 0.27567, epoch: 13/200, batch: 20/25, loss_gen: 1.068, loss_dis: 0.891
# ETA: 7.16279
#
# ETA: 0.27772, epoch: 14/200, batch: 0/25, loss_gen: 1.075, loss_dis: 0.889
# ETA: 0.27753, epoch: 14/200, batch: 10/25, loss_gen: 1.093, loss_dis: 0.882
# ETA: 0.27648, epoch: 14/200, batch: 20/25, loss_gen: 1.111, loss_dis: 0.869
# ETA: 7.26069
#
# ETA: 0.26240, epoch: 15/200, batch: 0/25, loss_gen: 1.119, loss_dis: 0.863
# ETA: 0.27750, epoch: 15/200, batch: 10/25, loss_gen: 1.134, loss_dis: 0.853
# ETA: 0.27599, epoch: 15/200, batch: 20/25, loss_gen: 1.143, loss_dis: 0.846
# ETA: 7.27182
#
# ETA: 0.27896, epoch: 16/200, batch: 0/25, loss_gen: 1.148, loss_dis: 0.844
# ETA: 0.27805, epoch: 16/200, batch: 10/25, loss_gen: 1.159, loss_dis: 0.835
# ETA: 0.27902, epoch: 16/200, batch: 20/25, loss_gen: 1.176, loss_dis: 0.824
# ETA: 7.28223
#
# ETA: 0.27519, epoch: 17/200, batch: 0/25, loss_gen: 1.187, loss_dis: 0.817
# ETA: 0.27358, epoch: 17/200, batch: 10/25, loss_gen: 1.200, loss_dis: 0.807
# ETA: 0.27770, epoch: 17/200, batch: 20/25, loss_gen: 1.211, loss_dis: 0.801
# ETA: 7.24352
#
# ETA: 0.27348, epoch: 18/200, batch: 0/25, loss_gen: 1.215, loss_dis: 0.800
# ETA: 0.27521, epoch: 18/200, batch: 10/25, loss_gen: 1.215, loss_dis: 0.806
# ETA: 0.27163, epoch: 18/200, batch: 20/25, loss_gen: 1.232, loss_dis: 0.797
# ETA: 7.22818
#
# ETA: 0.27391, epoch: 19/200, batch: 0/25, loss_gen: 1.247, loss_dis: 0.791
# ETA: 0.27683, epoch: 19/200, batch: 10/25, loss_gen: 1.271, loss_dis: 0.780
# ETA: 0.27739, epoch: 19/200, batch: 20/25, loss_gen: 1.285, loss_dis: 0.775
# ETA: 7.21970
#
# ETA: 0.27318, epoch: 20/200, batch: 0/25, loss_gen: 1.289, loss_dis: 0.776
# ETA: 0.27381, epoch: 20/200, batch: 10/25, loss_gen: 1.288, loss_dis: 0.783
# ETA: 0.27480, epoch: 20/200, batch: 20/25, loss_gen: 1.292, loss_dis: 0.781
# ETA: 7.23326
#
# ETA: 0.27268, epoch: 21/200, batch: 0/25, loss_gen: 1.296, loss_dis: 0.778
# ETA: 0.27884, epoch: 21/200, batch: 10/25, loss_gen: 1.301, loss_dis: 0.775
# ETA: 0.27646, epoch: 21/200, batch: 20/25, loss_gen: 1.307, loss_dis: 0.771
# ETA: 7.25162
#
# ETA: 0.27315, epoch: 22/200, batch: 0/25, loss_gen: 1.309, loss_dis: 0.770
# ETA: 0.27667, epoch: 22/200, batch: 10/25, loss_gen: 1.317, loss_dis: 0.765
# ETA: 0.27578, epoch: 22/200, batch: 20/25, loss_gen: 1.324, loss_dis: 0.760
# ETA: 7.28152
#
# ETA: 0.27754, epoch: 23/200, batch: 0/25, loss_gen: 1.329, loss_dis: 0.757
# ETA: 0.27645, epoch: 23/200, batch: 10/25, loss_gen: 1.343, loss_dis: 0.748
# ETA: 0.28175, epoch: 23/200, batch: 20/25, loss_gen: 1.355, loss_dis: 0.739
# ETA: 7.32614
#
# ETA: 0.27864, epoch: 24/200, batch: 0/25, loss_gen: 1.356, loss_dis: 0.738
# ETA: 0.28416, epoch: 24/200, batch: 10/25, loss_gen: 1.352, loss_dis: 0.741
# ETA: 0.28318, epoch: 24/200, batch: 20/25, loss_gen: 1.356, loss_dis: 0.743
# ETA: 7.38913
#
# ETA: 0.28246, epoch: 25/200, batch: 0/25, loss_gen: 1.360, loss_dis: 0.742
# ETA: 0.28120, epoch: 25/200, batch: 10/25, loss_gen: 1.368, loss_dis: 0.736
# ETA: 0.28779, epoch: 25/200, batch: 20/25, loss_gen: 1.379, loss_dis: 0.730
# ETA: 7.46258
#
# ETA: 0.28289, epoch: 26/200, batch: 0/25, loss_gen: 1.384, loss_dis: 0.727
# ETA: 0.28612, epoch: 26/200, batch: 10/25, loss_gen: 1.392, loss_dis: 0.723
# ETA: 0.28281, epoch: 26/200, batch: 20/25, loss_gen: 1.399, loss_dis: 0.718
# ETA: 7.51583
#
# ETA: 0.29093, epoch: 27/200, batch: 0/25, loss_gen: 1.404, loss_dis: 0.716
# ETA: 0.28924, epoch: 27/200, batch: 10/25, loss_gen: 1.414, loss_dis: 0.717
# ETA: 0.28847, epoch: 27/200, batch: 20/25, loss_gen: 1.417, loss_dis: 0.718
# ETA: 7.59989
#
# ETA: 0.29097, epoch: 28/200, batch: 0/25, loss_gen: 1.419, loss_dis: 0.717
# ETA: 0.28959, epoch: 28/200, batch: 10/25, loss_gen: 1.427, loss_dis: 0.712
# ETA: 0.28993, epoch: 28/200, batch: 20/25, loss_gen: 1.437, loss_dis: 0.706
# ETA: 7.61698
#
# ETA: 0.28933, epoch: 29/200, batch: 0/25, loss_gen: 1.444, loss_dis: 0.702
# ETA: 0.29130, epoch: 29/200, batch: 10/25, loss_gen: 1.455, loss_dis: 0.696
# ETA: 0.28879, epoch: 29/200, batch: 20/25, loss_gen: 1.460, loss_dis: 0.694
# ETA: 7.61218
#
# ETA: 0.28956, epoch: 30/200, batch: 0/25, loss_gen: 1.460, loss_dis: 0.694
# ETA: 0.29073, epoch: 30/200, batch: 10/25, loss_gen: 1.462, loss_dis: 0.693
# ETA: 0.28839, epoch: 30/200, batch: 20/25, loss_gen: 1.470, loss_dis: 0.696
# ETA: 7.56091
#
# ETA: 0.28637, epoch: 31/200, batch: 0/25, loss_gen: 1.471, loss_dis: 0.694
# ETA: 0.28289, epoch: 31/200, batch: 10/25, loss_gen: 1.475, loss_dis: 0.692
# ETA: 0.28311, epoch: 31/200, batch: 20/25, loss_gen: 1.480, loss_dis: 0.688
# ETA: 7.52313
#
# ETA: 0.28603, epoch: 32/200, batch: 0/25, loss_gen: 1.483, loss_dis: 0.686
# ETA: 0.28860, epoch: 32/200, batch: 10/25, loss_gen: 1.491, loss_dis: 0.684
# ETA: 0.28289, epoch: 32/200, batch: 20/25, loss_gen: 1.493, loss_dis: 0.684
# ETA: 7.50681
#
# ETA: 0.28709, epoch: 33/200, batch: 0/25, loss_gen: 1.496, loss_dis: 0.683
# ETA: 0.28516, epoch: 33/200, batch: 10/25, loss_gen: 1.501, loss_dis: 0.681
# ETA: 0.28137, epoch: 33/200, batch: 20/25, loss_gen: 1.510, loss_dis: 0.676
# ETA: 7.48620
#
# ETA: 0.28566, epoch: 34/200, batch: 0/25, loss_gen: 1.512, loss_dis: 0.674
# ETA: 0.28334, epoch: 34/200, batch: 10/25, loss_gen: 1.513, loss_dis: 0.672
# ETA: 0.28434, epoch: 34/200, batch: 20/25, loss_gen: 1.516, loss_dis: 0.670
# ETA: 7.47416
#
# ETA: 0.28463, epoch: 35/200, batch: 0/25, loss_gen: 1.519, loss_dis: 0.669
# ETA: 0.28242, epoch: 35/200, batch: 10/25, loss_gen: 1.524, loss_dis: 0.665
# ETA: 0.28484, epoch: 35/200, batch: 20/25, loss_gen: 1.525, loss_dis: 0.665
# ETA: 7.49937
#
# ETA: 0.28406, epoch: 36/200, batch: 0/25, loss_gen: 1.525, loss_dis: 0.665
# ETA: 0.28637, epoch: 36/200, batch: 10/25, loss_gen: 1.531, loss_dis: 0.662
# ETA: 0.28618, epoch: 36/200, batch: 20/25, loss_gen: 1.536, loss_dis: 0.658
# ETA: 7.50463
#
# ETA: 0.28539, epoch: 37/200, batch: 0/25, loss_gen: 1.540, loss_dis: 0.656
# ETA: 0.28557, epoch: 37/200, batch: 10/25, loss_gen: 1.544, loss_dis: 0.653
# ETA: 0.28730, epoch: 37/200, batch: 20/25, loss_gen: 1.546, loss_dis: 0.653
# ETA: 7.50922
#
# ETA: 0.28769, epoch: 38/200, batch: 0/25, loss_gen: 1.546, loss_dis: 0.652
# ETA: 0.28395, epoch: 38/200, batch: 10/25, loss_gen: 1.549, loss_dis: 0.650
# ETA: 0.28494, epoch: 38/200, batch: 20/25, loss_gen: 1.555, loss_dis: 0.647
# ETA: 7.53081
#
# ETA: 0.28990, epoch: 39/200, batch: 0/25, loss_gen: 1.557, loss_dis: 0.646
# ETA: 0.28500, epoch: 39/200, batch: 10/25, loss_gen: 1.563, loss_dis: 0.642
# ETA: 0.28572, epoch: 39/200, batch: 20/25, loss_gen: 1.566, loss_dis: 0.640
# ETA: 7.53670
#
# ETA: 0.28653, epoch: 40/200, batch: 0/25, loss_gen: 1.568, loss_dis: 0.639
# ETA: 0.28691, epoch: 40/200, batch: 10/25, loss_gen: 1.571, loss_dis: 0.640
# ETA: 0.28997, epoch: 40/200, batch: 20/25, loss_gen: 1.572, loss_dis: 0.639
# ETA: 7.54474
#
# ETA: 0.28831, epoch: 41/200, batch: 0/25, loss_gen: 1.573, loss_dis: 0.639
# ETA: 0.28912, epoch: 41/200, batch: 10/25, loss_gen: 1.579, loss_dis: 0.638
# ETA: 0.28432, epoch: 41/200, batch: 20/25, loss_gen: 1.587, loss_dis: 0.634
# ETA: 7.54347
#
# ETA: 0.28524, epoch: 42/200, batch: 0/25, loss_gen: 1.590, loss_dis: 0.633
# ETA: 0.28869, epoch: 42/200, batch: 10/25, loss_gen: 1.595, loss_dis: 0.631
# ETA: 0.28755, epoch: 42/200, batch: 20/25, loss_gen: 1.601, loss_dis: 0.632
# ETA: 7.54294
#
# ETA: 0.28861, epoch: 43/200, batch: 0/25, loss_gen: 1.603, loss_dis: 0.632
# ETA: 0.28514, epoch: 43/200, batch: 10/25, loss_gen: 1.605, loss_dis: 0.630
# ETA: 0.28761, epoch: 43/200, batch: 20/25, loss_gen: 1.612, loss_dis: 0.627
# ETA: 7.57151
#
# ETA: 0.28225, epoch: 44/200, batch: 0/25, loss_gen: 1.616, loss_dis: 0.625
# ETA: 0.29082, epoch: 44/200, batch: 10/25, loss_gen: 1.622, loss_dis: 0.623
# ETA: 0.29082, epoch: 44/200, batch: 20/25, loss_gen: 1.621, loss_dis: 0.623
# ETA: 7.56604
#
# ETA: 0.28857, epoch: 45/200, batch: 0/25, loss_gen: 1.620, loss_dis: 0.625
# ETA: 0.29024, epoch: 45/200, batch: 10/25, loss_gen: 1.619, loss_dis: 0.625
# ETA: 0.28858, epoch: 45/200, batch: 20/25, loss_gen: 1.620, loss_dis: 0.623
# ETA: 7.61201
#
# ETA: 0.28898, epoch: 46/200, batch: 0/25, loss_gen: 1.622, loss_dis: 0.623
# ETA: 0.29137, epoch: 46/200, batch: 10/25, loss_gen: 1.624, loss_dis: 0.622
# ETA: 0.29048, epoch: 46/200, batch: 20/25, loss_gen: 1.627, loss_dis: 0.620
# ETA: 7.61998
#
# ETA: 0.28860, epoch: 47/200, batch: 0/25, loss_gen: 1.628, loss_dis: 0.619
# ETA: 0.28962, epoch: 47/200, batch: 10/25, loss_gen: 1.633, loss_dis: 0.618
# ETA: 0.28829, epoch: 47/200, batch: 20/25, loss_gen: 1.638, loss_dis: 0.616
# ETA: 7.61398
#
# ETA: 0.28900, epoch: 48/200, batch: 0/25, loss_gen: 1.639, loss_dis: 0.620
# ETA: 0.28946, epoch: 48/200, batch: 10/25, loss_gen: 1.642, loss_dis: 0.620
# ETA: 0.28693, epoch: 48/200, batch: 20/25, loss_gen: 1.645, loss_dis: 0.619
# ETA: 7.62129
#
# ETA: 0.28988, epoch: 49/200, batch: 0/25, loss_gen: 1.647, loss_dis: 0.620
# ETA: 0.28781, epoch: 49/200, batch: 10/25, loss_gen: 1.649, loss_dis: 0.618
# ETA: 0.28825, epoch: 49/200, batch: 20/25, loss_gen: 1.650, loss_dis: 0.616
# ETA: 7.58883
#
# ETA: 0.28844, epoch: 50/200, batch: 0/25, loss_gen: 1.652, loss_dis: 0.615
# ETA: 0.28729, epoch: 50/200, batch: 10/25, loss_gen: 1.654, loss_dis: 0.613
# ETA: 0.28819, epoch: 50/200, batch: 20/25, loss_gen: 1.658, loss_dis: 0.610
# ETA: 7.56982
#
# ETA: 0.29009, epoch: 51/200, batch: 0/25, loss_gen: 1.659, loss_dis: 0.609
# ETA: 0.28851, epoch: 51/200, batch: 10/25, loss_gen: 1.665, loss_dis: 0.606
# ETA: 0.28913, epoch: 51/200, batch: 20/25, loss_gen: 1.670, loss_dis: 0.603
# ETA: 7.57084
#
# ETA: 0.28751, epoch: 52/200, batch: 0/25, loss_gen: 1.669, loss_dis: 0.602
# ETA: 0.28888, epoch: 52/200, batch: 10/25, loss_gen: 1.668, loss_dis: 0.603
# ETA: 0.29146, epoch: 52/200, batch: 20/25, loss_gen: 1.670, loss_dis: 0.601
# ETA: 7.58999
#
# ETA: 0.29073, epoch: 53/200, batch: 0/25, loss_gen: 1.672, loss_dis: 0.601
# ETA: 0.28818, epoch: 53/200, batch: 10/25, loss_gen: 1.679, loss_dis: 0.598
# ETA: 0.29049, epoch: 53/200, batch: 20/25, loss_gen: 1.685, loss_dis: 0.597
# ETA: 7.61600
#
# ETA: 0.28813, epoch: 54/200, batch: 0/25, loss_gen: 1.689, loss_dis: 0.596
# ETA: 0.28857, epoch: 54/200, batch: 10/25, loss_gen: 1.705, loss_dis: 0.596
# ETA: 0.28961, epoch: 54/200, batch: 20/25, loss_gen: 1.710, loss_dis: 0.594
# ETA: 7.60235
#
# ETA: 0.28683, epoch: 55/200, batch: 0/25, loss_gen: 1.711, loss_dis: 0.593
# ETA: 0.28878, epoch: 55/200, batch: 10/25, loss_gen: 1.714, loss_dis: 0.592
# ETA: 0.29130, epoch: 55/200, batch: 20/25, loss_gen: 1.718, loss_dis: 0.590
# ETA: 7.60535
#
# ETA: 0.28952, epoch: 56/200, batch: 0/25, loss_gen: 1.718, loss_dis: 0.589
# ETA: 0.28979, epoch: 56/200, batch: 10/25, loss_gen: 1.721, loss_dis: 0.588
# ETA: 0.28926, epoch: 56/200, batch: 20/25, loss_gen: 1.726, loss_dis: 0.586
# ETA: 7.61953
#
# ETA: 0.28876, epoch: 57/200, batch: 0/25, loss_gen: 1.729, loss_dis: 0.584
# ETA: 0.28754, epoch: 57/200, batch: 10/25, loss_gen: 1.734, loss_dis: 0.582
# ETA: 0.28837, epoch: 57/200, batch: 20/25, loss_gen: 1.735, loss_dis: 0.581
# ETA: 7.56942
#
# ETA: 0.28519, epoch: 58/200, batch: 0/25, loss_gen: 1.735, loss_dis: 0.580
# ETA: 0.28863, epoch: 58/200, batch: 10/25, loss_gen: 1.742, loss_dis: 0.581
# ETA: 0.28171, epoch: 58/200, batch: 20/25, loss_gen: 1.747, loss_dis: 0.580
# ETA: 7.56723
#
# ETA: 0.28629, epoch: 59/200, batch: 0/25, loss_gen: 1.747, loss_dis: 0.581
# ETA: 0.28260, epoch: 59/200, batch: 10/25, loss_gen: 1.749, loss_dis: 0.579
# ETA: 0.28923, epoch: 59/200, batch: 20/25, loss_gen: 1.750, loss_dis: 0.578
# ETA: 7.55410
#
# ETA: 0.28840, epoch: 60/200, batch: 0/25, loss_gen: 1.752, loss_dis: 0.577
# ETA: 0.28967, epoch: 60/200, batch: 10/25, loss_gen: 1.756, loss_dis: 0.575
# ETA: 0.28540, epoch: 60/200, batch: 20/25, loss_gen: 1.762, loss_dis: 0.575
# ETA: 7.55894
#
# ETA: 0.28762, epoch: 61/200, batch: 0/25, loss_gen: 1.763, loss_dis: 0.574
# ETA: 0.28619, epoch: 61/200, batch: 10/25, loss_gen: 1.765, loss_dis: 0.573
# ETA: 0.28774, epoch: 61/200, batch: 20/25, loss_gen: 1.769, loss_dis: 0.571
# ETA: 7.54928
#
# ETA: 0.28729, epoch: 62/200, batch: 0/25, loss_gen: 1.771, loss_dis: 0.570
# ETA: 0.28467, epoch: 62/200, batch: 10/25, loss_gen: 1.776, loss_dis: 0.568
# ETA: 0.28428, epoch: 62/200, batch: 20/25, loss_gen: 1.784, loss_dis: 0.565
# ETA: 7.57497
#
# ETA: 0.28780, epoch: 63/200, batch: 0/25, loss_gen: 1.787, loss_dis: 0.564
# ETA: 0.28924, epoch: 63/200, batch: 10/25, loss_gen: 1.790, loss_dis: 0.562
# ETA: 0.28880, epoch: 63/200, batch: 20/25, loss_gen: 1.794, loss_dis: 0.565
# ETA: 7.56075
#
# ETA: 0.28713, epoch: 64/200, batch: 0/25, loss_gen: 1.798, loss_dis: 0.566
# ETA: 0.28597, epoch: 64/200, batch: 10/25, loss_gen: 1.804, loss_dis: 0.566
# ETA: 0.28772, epoch: 64/200, batch: 20/25, loss_gen: 1.806, loss_dis: 0.565
# ETA: 7.55658
#
# ETA: 0.28560, epoch: 65/200, batch: 0/25, loss_gen: 1.807, loss_dis: 0.565
# ETA: 0.29068, epoch: 65/200, batch: 10/25, loss_gen: 1.809, loss_dis: 0.564
# ETA: 0.28556, epoch: 65/200, batch: 20/25, loss_gen: 1.812, loss_dis: 0.563
# ETA: 7.54711
#
# ETA: 0.28772, epoch: 66/200, batch: 0/25, loss_gen: 1.812, loss_dis: 0.563
# ETA: 0.28922, epoch: 66/200, batch: 10/25, loss_gen: 1.818, loss_dis: 0.562
# ETA: 0.28779, epoch: 66/200, batch: 20/25, loss_gen: 1.820, loss_dis: 0.560
# ETA: 7.55777
#
# ETA: 0.28645, epoch: 67/200, batch: 0/25, loss_gen: 1.820, loss_dis: 0.560
# ETA: 0.28690, epoch: 67/200, batch: 10/25, loss_gen: 1.823, loss_dis: 0.558
# ETA: 0.28814, epoch: 67/200, batch: 20/25, loss_gen: 1.823, loss_dis: 0.557
# ETA: 7.56308
#
# ETA: 0.29041, epoch: 68/200, batch: 0/25, loss_gen: 1.823, loss_dis: 0.557
# ETA: 0.29037, epoch: 68/200, batch: 10/25, loss_gen: 1.824, loss_dis: 0.556
# ETA: 0.28848, epoch: 68/200, batch: 20/25, loss_gen: 1.824, loss_dis: 0.557
# ETA: 7.60740
#
# ETA: 0.28381, epoch: 69/200, batch: 0/25, loss_gen: 1.826, loss_dis: 0.557
# ETA: 0.28489, epoch: 69/200, batch: 10/25, loss_gen: 1.832, loss_dis: 0.557
# ETA: 0.29155, epoch: 69/200, batch: 20/25, loss_gen: 1.834, loss_dis: 0.555
# ETA: 7.58536
#
# ETA: 0.28866, epoch: 70/200, batch: 0/25, loss_gen: 1.835, loss_dis: 0.554
# ETA: 0.28391, epoch: 70/200, batch: 10/25, loss_gen: 1.838, loss_dis: 0.552
# ETA: 0.28993, epoch: 70/200, batch: 20/25, loss_gen: 1.839, loss_dis: 0.551
# ETA: 7.55110
#
# ETA: 0.28945, epoch: 71/200, batch: 0/25, loss_gen: 1.838, loss_dis: 0.551
# ETA: 0.29013, epoch: 71/200, batch: 10/25, loss_gen: 1.836, loss_dis: 0.553
# ETA: 0.28733, epoch: 71/200, batch: 20/25, loss_gen: 1.837, loss_dis: 0.552
# ETA: 7.56314
#
# ETA: 0.28685, epoch: 72/200, batch: 0/25, loss_gen: 1.839, loss_dis: 0.551
# ETA: 0.28891, epoch: 72/200, batch: 10/25, loss_gen: 1.844, loss_dis: 0.554
# ETA: 0.28934, epoch: 72/200, batch: 20/25, loss_gen: 1.844, loss_dis: 0.554
# ETA: 7.60456
#
# ETA: 0.28865, epoch: 73/200, batch: 0/25, loss_gen: 1.845, loss_dis: 0.553
# ETA: 0.29090, epoch: 73/200, batch: 10/25, loss_gen: 1.848, loss_dis: 0.551
# ETA: 0.28705, epoch: 73/200, batch: 20/25, loss_gen: 1.849, loss_dis: 0.550
# ETA: 7.59561
#
# ETA: 0.28808, epoch: 74/200, batch: 0/25, loss_gen: 1.849, loss_dis: 0.550
# ETA: 0.29006, epoch: 74/200, batch: 10/25, loss_gen: 1.849, loss_dis: 0.550
# ETA: 0.28998, epoch: 74/200, batch: 20/25, loss_gen: 1.849, loss_dis: 0.549
# ETA: 7.59537
#
# ETA: 0.28438, epoch: 75/200, batch: 0/25, loss_gen: 1.849, loss_dis: 0.548
# ETA: 0.28476, epoch: 75/200, batch: 10/25, loss_gen: 1.851, loss_dis: 0.547
# ETA: 0.28514, epoch: 75/200, batch: 20/25, loss_gen: 1.851, loss_dis: 0.546
# ETA: 7.56065
#
# ETA: 0.28559, epoch: 76/200, batch: 0/25, loss_gen: 1.851, loss_dis: 0.546
# ETA: 0.28964, epoch: 76/200, batch: 10/25, loss_gen: 1.855, loss_dis: 0.545
# ETA: 0.29005, epoch: 76/200, batch: 20/25, loss_gen: 1.855, loss_dis: 0.547
# ETA: 7.53413
#
# ETA: 0.28806, epoch: 77/200, batch: 0/25, loss_gen: 1.855, loss_dis: 0.547
# ETA: 0.28806, epoch: 77/200, batch: 10/25, loss_gen: 1.859, loss_dis: 0.545
# ETA: 0.28591, epoch: 77/200, batch: 20/25, loss_gen: 1.861, loss_dis: 0.543
# ETA: 7.56238
#
# ETA: 0.28877, epoch: 78/200, batch: 0/25, loss_gen: 1.861, loss_dis: 0.543
# ETA: 0.28885, epoch: 78/200, batch: 10/25, loss_gen: 1.863, loss_dis: 0.541
# ETA: 0.28756, epoch: 78/200, batch: 20/25, loss_gen: 1.863, loss_dis: 0.540
# ETA: 7.57854
#
# ETA: 0.28874, epoch: 79/200, batch: 0/25, loss_gen: 1.863, loss_dis: 0.540
# ETA: 0.28816, epoch: 79/200, batch: 10/25, loss_gen: 1.863, loss_dis: 0.539
# ETA: 0.29164, epoch: 79/200, batch: 20/25, loss_gen: 1.866, loss_dis: 0.541
# ETA: 7.59654
#
# ETA: 0.28898, epoch: 80/200, batch: 0/25, loss_gen: 1.869, loss_dis: 0.541
# ETA: 0.28611, epoch: 80/200, batch: 10/25, loss_gen: 1.870, loss_dis: 0.541
# ETA: 0.28865, epoch: 80/200, batch: 20/25, loss_gen: 1.870, loss_dis: 0.541
# ETA: 7.58019
#
# ETA: 0.28758, epoch: 81/200, batch: 0/25, loss_gen: 1.870, loss_dis: 0.541
# ETA: 0.28471, epoch: 81/200, batch: 10/25, loss_gen: 1.870, loss_dis: 0.541
# ETA: 0.28838, epoch: 81/200, batch: 20/25, loss_gen: 1.870, loss_dis: 0.540
# ETA: 7.53469
#
# ETA: 0.28680, epoch: 82/200, batch: 0/25, loss_gen: 1.871, loss_dis: 0.539
# ETA: 0.28342, epoch: 82/200, batch: 10/25, loss_gen: 1.875, loss_dis: 0.538
# ETA: 0.28769, epoch: 82/200, batch: 20/25, loss_gen: 1.877, loss_dis: 0.536
# ETA: 7.52564
#
# ETA: 0.28519, epoch: 83/200, batch: 0/25, loss_gen: 1.878, loss_dis: 0.536
# ETA: 0.28666, epoch: 83/200, batch: 10/25, loss_gen: 1.879, loss_dis: 0.536
# ETA: 0.28735, epoch: 83/200, batch: 20/25, loss_gen: 1.881, loss_dis: 0.536
# ETA: 7.50590
#
# ETA: 0.28142, epoch: 84/200, batch: 0/25, loss_gen: 1.882, loss_dis: 0.536
# ETA: 0.28569, epoch: 84/200, batch: 10/25, loss_gen: 1.884, loss_dis: 0.535
# ETA: 0.28559, epoch: 84/200, batch: 20/25, loss_gen: 1.885, loss_dis: 0.534
# ETA: 7.49662
#
# ETA: 0.28529, epoch: 85/200, batch: 0/25, loss_gen: 1.886, loss_dis: 0.534
# ETA: 0.28584, epoch: 85/200, batch: 10/25, loss_gen: 1.888, loss_dis: 0.533
# ETA: 0.28679, epoch: 85/200, batch: 20/25, loss_gen: 1.890, loss_dis: 0.532
# ETA: 7.53795
#
# ETA: 0.28409, epoch: 86/200, batch: 0/25, loss_gen: 1.891, loss_dis: 0.531
# ETA: 0.28854, epoch: 86/200, batch: 10/25, loss_gen: 1.895, loss_dis: 0.530
# ETA: 0.28926, epoch: 86/200, batch: 20/25, loss_gen: 1.897, loss_dis: 0.529
# ETA: 7.56281
#
# ETA: 0.28973, epoch: 87/200, batch: 0/25, loss_gen: 1.898, loss_dis: 0.530
# ETA: 0.29070, epoch: 87/200, batch: 10/25, loss_gen: 1.904, loss_dis: 0.532
# ETA: 0.28904, epoch: 87/200, batch: 20/25, loss_gen: 1.910, loss_dis: 0.533
# ETA: 7.62258
#
# ETA: 0.29022, epoch: 88/200, batch: 0/25, loss_gen: 1.911, loss_dis: 0.534
# ETA: 0.29173, epoch: 88/200, batch: 10/25, loss_gen: 1.912, loss_dis: 0.534
# ETA: 0.28900, epoch: 88/200, batch: 20/25, loss_gen: 1.912, loss_dis: 0.533
# ETA: 7.61751
#
# ETA: 0.29030, epoch: 89/200, batch: 0/25, loss_gen: 1.914, loss_dis: 0.532
# ETA: 0.28970, epoch: 89/200, batch: 10/25, loss_gen: 1.917, loss_dis: 0.531
# ETA: 0.28943, epoch: 89/200, batch: 20/25, loss_gen: 1.919, loss_dis: 0.530
# ETA: 7.60704
#
# ETA: 0.28964, epoch: 90/200, batch: 0/25, loss_gen: 1.919, loss_dis: 0.529
# ETA: 0.28967, epoch: 90/200, batch: 10/25, loss_gen: 1.917, loss_dis: 0.530
# ETA: 0.29189, epoch: 90/200, batch: 20/25, loss_gen: 1.917, loss_dis: 0.530
# ETA: 7.61741
#
# ETA: 0.28856, epoch: 91/200, batch: 0/25, loss_gen: 1.917, loss_dis: 0.530
# ETA: 0.28848, epoch: 91/200, batch: 10/25, loss_gen: 1.917, loss_dis: 0.530
# ETA: 0.29035, epoch: 91/200, batch: 20/25, loss_gen: 1.919, loss_dis: 0.529
# ETA: 7.61869
#
# ETA: 0.28910, epoch: 92/200, batch: 0/25, loss_gen: 1.919, loss_dis: 0.528
# ETA: 0.28676, epoch: 92/200, batch: 10/25, loss_gen: 1.919, loss_dis: 0.531
# ETA: 0.28815, epoch: 92/200, batch: 20/25, loss_gen: 1.921, loss_dis: 0.530
# ETA: 7.57899
#
# ETA: 0.28810, epoch: 93/200, batch: 0/25, loss_gen: 1.921, loss_dis: 0.530
# ETA: 0.28745, epoch: 93/200, batch: 10/25, loss_gen: 1.922, loss_dis: 0.529
# ETA: 0.28394, epoch: 93/200, batch: 20/25, loss_gen: 1.922, loss_dis: 0.529
# ETA: 7.54143
#
# ETA: 0.28530, epoch: 94/200, batch: 0/25, loss_gen: 1.922, loss_dis: 0.528
# ETA: 0.28424, epoch: 94/200, batch: 10/25, loss_gen: 1.923, loss_dis: 0.527
# ETA: 0.28507, epoch: 94/200, batch: 20/25, loss_gen: 1.923, loss_dis: 0.527
# ETA: 7.47591
#
# ETA: 0.28762, epoch: 95/200, batch: 0/25, loss_gen: 1.922, loss_dis: 0.527
# ETA: 0.28037, epoch: 95/200, batch: 10/25, loss_gen: 1.922, loss_dis: 0.527
# ETA: 0.28524, epoch: 95/200, batch: 20/25, loss_gen: 1.928, loss_dis: 0.529
# ETA: 7.45039
#
# ETA: 0.28389, epoch: 96/200, batch: 0/25, loss_gen: 1.933, loss_dis: 0.529
# ETA: 0.28613, epoch: 96/200, batch: 10/25, loss_gen: 1.933, loss_dis: 0.528
# ETA: 0.28153, epoch: 96/200, batch: 20/25, loss_gen: 1.933, loss_dis: 0.528
# ETA: 7.47323
#
# ETA: 0.28548, epoch: 97/200, batch: 0/25, loss_gen: 1.933, loss_dis: 0.527
# ETA: 0.28841, epoch: 97/200, batch: 10/25, loss_gen: 1.934, loss_dis: 0.526
# ETA: 0.28650, epoch: 97/200, batch: 20/25, loss_gen: 1.936, loss_dis: 0.525
# ETA: 7.53111
#
# ETA: 0.28943, epoch: 98/200, batch: 0/25, loss_gen: 1.936, loss_dis: 0.524
# ETA: 0.28942, epoch: 98/200, batch: 10/25, loss_gen: 1.939, loss_dis: 0.523
# ETA: 0.28955, epoch: 98/200, batch: 20/25, loss_gen: 1.941, loss_dis: 0.522
# ETA: 7.61997
#
# ETA: 0.28952, epoch: 99/200, batch: 0/25, loss_gen: 1.941, loss_dis: 0.521
# ETA: 0.29023, epoch: 99/200, batch: 10/25, loss_gen: 1.942, loss_dis: 0.522
# ETA: 0.29067, epoch: 99/200, batch: 20/25, loss_gen: 1.952, loss_dis: 0.526
# ETA: 7.61588
#
# ETA: 0.29008, epoch: 100/200, batch: 0/25, loss_gen: 1.953, loss_dis: 0.527
# ETA: 0.29031, epoch: 100/200, batch: 10/25, loss_gen: 1.955, loss_dis: 0.527
# ETA: 0.28974, epoch: 100/200, batch: 20/25, loss_gen: 1.956, loss_dis: 0.526
# ETA: 7.61635
#
# ETA: 0.28915, epoch: 101/200, batch: 0/25, loss_gen: 1.957, loss_dis: 0.526
# ETA: 0.28654, epoch: 101/200, batch: 10/25, loss_gen: 1.962, loss_dis: 0.525
# ETA: 0.28860, epoch: 101/200, batch: 20/25, loss_gen: 1.965, loss_dis: 0.525
# ETA: 7.61293
#
# ETA: 0.28885, epoch: 102/200, batch: 0/25, loss_gen: 1.965, loss_dis: 0.525
# ETA: 0.28918, epoch: 102/200, batch: 10/25, loss_gen: 1.966, loss_dis: 0.524
# ETA: 0.29041, epoch: 102/200, batch: 20/25, loss_gen: 1.966, loss_dis: 0.524
# ETA: 7.61648
#
# ETA: 0.28949, epoch: 103/200, batch: 0/25, loss_gen: 1.967, loss_dis: 0.525
# ETA: 0.29000, epoch: 103/200, batch: 10/25, loss_gen: 1.968, loss_dis: 0.525
# ETA: 0.28748, epoch: 103/200, batch: 20/25, loss_gen: 1.968, loss_dis: 0.524
# ETA: 7.57218
#
# ETA: 0.28697, epoch: 104/200, batch: 0/25, loss_gen: 1.968, loss_dis: 0.525
# ETA: 0.28768, epoch: 104/200, batch: 10/25, loss_gen: 1.970, loss_dis: 0.525
# ETA: 0.28609, epoch: 104/200, batch: 20/25, loss_gen: 1.970, loss_dis: 0.524
# ETA: 7.51334
#
# ETA: 0.28449, epoch: 105/200, batch: 0/25, loss_gen: 1.970, loss_dis: 0.524
# ETA: 0.28269, epoch: 105/200, batch: 10/25, loss_gen: 1.970, loss_dis: 0.523
# ETA: 0.28669, epoch: 105/200, batch: 20/25, loss_gen: 1.970, loss_dis: 0.523
# ETA: 7.48317
#
# ETA: 0.28588, epoch: 106/200, batch: 0/25, loss_gen: 1.970, loss_dis: 0.523
# ETA: 0.28457, epoch: 106/200, batch: 10/25, loss_gen: 1.972, loss_dis: 0.521
# ETA: 0.28145, epoch: 106/200, batch: 20/25, loss_gen: 1.974, loss_dis: 0.520
# ETA: 7.47497
#
# ETA: 0.28696, epoch: 107/200, batch: 0/25, loss_gen: 1.975, loss_dis: 0.520
# ETA: 0.28130, epoch: 107/200, batch: 10/25, loss_gen: 1.974, loss_dis: 0.520
# ETA: 0.28539, epoch: 107/200, batch: 20/25, loss_gen: 1.974, loss_dis: 0.522
# ETA: 7.48831
#
# ETA: 0.28620, epoch: 108/200, batch: 0/25, loss_gen: 1.978, loss_dis: 0.524
# ETA: 0.28616, epoch: 108/200, batch: 10/25, loss_gen: 1.979, loss_dis: 0.523
# ETA: 0.28542, epoch: 108/200, batch: 20/25, loss_gen: 1.980, loss_dis: 0.524
# ETA: 7.53231
#
# ETA: 0.28785, epoch: 109/200, batch: 0/25, loss_gen: 1.980, loss_dis: 0.523
# ETA: 0.28804, epoch: 109/200, batch: 10/25, loss_gen: 1.978, loss_dis: 0.524
# ETA: 0.28894, epoch: 109/200, batch: 20/25, loss_gen: 1.979, loss_dis: 0.523
# ETA: 7.57338
#
# ETA: 0.28882, epoch: 110/200, batch: 0/25, loss_gen: 1.979, loss_dis: 0.522
# ETA: 0.28917, epoch: 110/200, batch: 10/25, loss_gen: 1.981, loss_dis: 0.521
# ETA: 0.28916, epoch: 110/200, batch: 20/25, loss_gen: 1.983, loss_dis: 0.520
# ETA: 7.62401
#
# ETA: 0.29102, epoch: 111/200, batch: 0/25, loss_gen: 1.984, loss_dis: 0.520
# ETA: 0.28965, epoch: 111/200, batch: 10/25, loss_gen: 1.986, loss_dis: 0.518
# ETA: 0.28721, epoch: 111/200, batch: 20/25, loss_gen: 1.988, loss_dis: 0.517
# ETA: 7.61797
#
# ETA: 0.28962, epoch: 112/200, batch: 0/25, loss_gen: 1.989, loss_dis: 0.517
# ETA: 0.29074, epoch: 112/200, batch: 10/25, loss_gen: 1.990, loss_dis: 0.516
# ETA: 0.29000, epoch: 112/200, batch: 20/25, loss_gen: 1.990, loss_dis: 0.515
# ETA: 7.62174
#
# ETA: 0.28988, epoch: 113/200, batch: 0/25, loss_gen: 1.988, loss_dis: 0.516
# ETA: 0.28981, epoch: 113/200, batch: 10/25, loss_gen: 1.991, loss_dis: 0.517
# ETA: 0.28912, epoch: 113/200, batch: 20/25, loss_gen: 1.991, loss_dis: 0.517
# ETA: 7.62580
#
# ETA: 0.28939, epoch: 114/200, batch: 0/25, loss_gen: 1.994, loss_dis: 0.516
# ETA: 0.28950, epoch: 114/200, batch: 10/25, loss_gen: 1.996, loss_dis: 0.516
# ETA: 0.28851, epoch: 114/200, batch: 20/25, loss_gen: 1.997, loss_dis: 0.516
# ETA: 7.60275
#
# ETA: 0.28915, epoch: 115/200, batch: 0/25, loss_gen: 1.997, loss_dis: 0.516
# ETA: 0.28799, epoch: 115/200, batch: 10/25, loss_gen: 1.998, loss_dis: 0.515
# ETA: 0.28957, epoch: 115/200, batch: 20/25, loss_gen: 2.000, loss_dis: 0.514
# ETA: 7.57179
#
# ETA: 0.28177, epoch: 116/200, batch: 0/25, loss_gen: 2.000, loss_dis: 0.514
# ETA: 0.28873, epoch: 116/200, batch: 10/25, loss_gen: 2.002, loss_dis: 0.513
# ETA: 0.28933, epoch: 116/200, batch: 20/25, loss_gen: 2.002, loss_dis: 0.513
# ETA: 7.56077
#
# ETA: 0.28841, epoch: 117/200, batch: 0/25, loss_gen: 2.001, loss_dis: 0.513
# ETA: 0.28852, epoch: 117/200, batch: 10/25, loss_gen: 2.000, loss_dis: 0.513
# ETA: 0.28946, epoch: 117/200, batch: 20/25, loss_gen: 2.001, loss_dis: 0.513
# ETA: 7.57858
#
# ETA: 0.28912, epoch: 118/200, batch: 0/25, loss_gen: 2.002, loss_dis: 0.513
# ETA: 0.28987, epoch: 118/200, batch: 10/25, loss_gen: 2.004, loss_dis: 0.512
# ETA: 0.29005, epoch: 118/200, batch: 20/25, loss_gen: 2.004, loss_dis: 0.511
# ETA: 7.61444
#
# ETA: 0.28876, epoch: 119/200, batch: 0/25, loss_gen: 2.004, loss_dis: 0.511
# ETA: 0.28786, epoch: 119/200, batch: 10/25, loss_gen: 2.005, loss_dis: 0.510
# ETA: 0.28891, epoch: 119/200, batch: 20/25, loss_gen: 2.004, loss_dis: 0.510
# ETA: 7.61199
#
# ETA: 0.28906, epoch: 120/200, batch: 0/25, loss_gen: 2.003, loss_dis: 0.510
# ETA: 0.29060, epoch: 120/200, batch: 10/25, loss_gen: 2.002, loss_dis: 0.510
# ETA: 0.28981, epoch: 120/200, batch: 20/25, loss_gen: 2.002, loss_dis: 0.510
# ETA: 7.60597
#
# ETA: 0.28715, epoch: 121/200, batch: 0/25, loss_gen: 2.002, loss_dis: 0.510
# ETA: 0.28362, epoch: 121/200, batch: 10/25, loss_gen: 2.003, loss_dis: 0.509
# ETA: 0.28968, epoch: 121/200, batch: 20/25, loss_gen: 2.004, loss_dis: 0.508
# ETA: 7.60720
#
# ETA: 0.28780, epoch: 122/200, batch: 0/25, loss_gen: 2.004, loss_dis: 0.508
# ETA: 0.28839, epoch: 122/200, batch: 10/25, loss_gen: 2.004, loss_dis: 0.507
# ETA: 0.28863, epoch: 122/200, batch: 20/25, loss_gen: 2.004, loss_dis: 0.507
# ETA: 7.53644
#
# ETA: 0.28659, epoch: 123/200, batch: 0/25, loss_gen: 2.003, loss_dis: 0.507
# ETA: 0.28754, epoch: 123/200, batch: 10/25, loss_gen: 2.004, loss_dis: 0.506
# ETA: 0.28350, epoch: 123/200, batch: 20/25, loss_gen: 2.006, loss_dis: 0.506
# ETA: 7.54859
#
# ETA: 0.28877, epoch: 124/200, batch: 0/25, loss_gen: 2.009, loss_dis: 0.505
# ETA: 0.28744, epoch: 124/200, batch: 10/25, loss_gen: 2.012, loss_dis: 0.505
# ETA: 0.28873, epoch: 124/200, batch: 20/25, loss_gen: 2.022, loss_dis: 0.505
# ETA: 7.56902
#
# ETA: 0.28795, epoch: 125/200, batch: 0/25, loss_gen: 2.024, loss_dis: 0.506
# ETA: 0.28908, epoch: 125/200, batch: 10/25, loss_gen: 2.023, loss_dis: 0.506
# ETA: 0.29069, epoch: 125/200, batch: 20/25, loss_gen: 2.024, loss_dis: 0.506
# ETA: 7.57104
#
# ETA: 0.29091, epoch: 126/200, batch: 0/25, loss_gen: 2.024, loss_dis: 0.506
# ETA: 0.28862, epoch: 126/200, batch: 10/25, loss_gen: 2.030, loss_dis: 0.507
# ETA: 0.28665, epoch: 126/200, batch: 20/25, loss_gen: 2.030, loss_dis: 0.507
# ETA: 7.57476
#
# ETA: 0.28482, epoch: 127/200, batch: 0/25, loss_gen: 2.030, loss_dis: 0.507
# ETA: 0.29054, epoch: 127/200, batch: 10/25, loss_gen: 2.031, loss_dis: 0.506
# ETA: 0.28953, epoch: 127/200, batch: 20/25, loss_gen: 2.032, loss_dis: 0.505
# ETA: 7.58121
#
# ETA: 0.28869, epoch: 128/200, batch: 0/25, loss_gen: 2.032, loss_dis: 0.505
# ETA: 0.28381, epoch: 128/200, batch: 10/25, loss_gen: 2.032, loss_dis: 0.505
# ETA: 0.29068, epoch: 128/200, batch: 20/25, loss_gen: 2.032, loss_dis: 0.504
# ETA: 7.57500
#
# ETA: 0.28880, epoch: 129/200, batch: 0/25, loss_gen: 2.031, loss_dis: 0.504
# ETA: 0.28910, epoch: 129/200, batch: 10/25, loss_gen: 2.031, loss_dis: 0.505
# ETA: 0.28652, epoch: 129/200, batch: 20/25, loss_gen: 2.033, loss_dis: 0.504
# ETA: 7.57933
#
# ETA: 0.28980, epoch: 130/200, batch: 0/25, loss_gen: 2.034, loss_dis: 0.503
# ETA: 0.28878, epoch: 130/200, batch: 10/25, loss_gen: 2.035, loss_dis: 0.503
# ETA: 0.28947, epoch: 130/200, batch: 20/25, loss_gen: 2.035, loss_dis: 0.502
# ETA: 7.57582
#
# ETA: 0.28699, epoch: 131/200, batch: 0/25, loss_gen: 2.036, loss_dis: 0.502
# ETA: 0.28479, epoch: 131/200, batch: 10/25, loss_gen: 2.038, loss_dis: 0.501
# ETA: 0.28658, epoch: 131/200, batch: 20/25, loss_gen: 2.040, loss_dis: 0.500
# ETA: 7.54045
#
# ETA: 0.28838, epoch: 132/200, batch: 0/25, loss_gen: 2.042, loss_dis: 0.499
# ETA: 0.28817, epoch: 132/200, batch: 10/25, loss_gen: 2.045, loss_dis: 0.499
# ETA: 0.28401, epoch: 132/200, batch: 20/25, loss_gen: 2.048, loss_dis: 0.497
# ETA: 7.53361
#
# ETA: 0.28639, epoch: 133/200, batch: 0/25, loss_gen: 2.048, loss_dis: 0.497
# ETA: 0.28884, epoch: 133/200, batch: 10/25, loss_gen: 2.052, loss_dis: 0.501
# ETA: 0.28701, epoch: 133/200, batch: 20/25, loss_gen: 2.053, loss_dis: 0.501
# ETA: 7.57832
#
# ETA: 0.29062, epoch: 134/200, batch: 0/25, loss_gen: 2.053, loss_dis: 0.501
# ETA: 0.28862, epoch: 134/200, batch: 10/25, loss_gen: 2.055, loss_dis: 0.500
# ETA: 0.28920, epoch: 134/200, batch: 20/25, loss_gen: 2.058, loss_dis: 0.499
# ETA: 7.57812
#
# ETA: 0.28955, epoch: 135/200, batch: 0/25, loss_gen: 2.059, loss_dis: 0.499
# ETA: 0.28449, epoch: 135/200, batch: 10/25, loss_gen: 2.061, loss_dis: 0.498
# ETA: 0.28714, epoch: 135/200, batch: 20/25, loss_gen: 2.062, loss_dis: 0.498
# ETA: 7.57081
#
# ETA: 0.28239, epoch: 136/200, batch: 0/25, loss_gen: 2.063, loss_dis: 0.498
# ETA: 0.28936, epoch: 136/200, batch: 10/25, loss_gen: 2.064, loss_dis: 0.498
# ETA: 0.28871, epoch: 136/200, batch: 20/25, loss_gen: 2.066, loss_dis: 0.498
# ETA: 7.55360
#
# ETA: 0.28789, epoch: 137/200, batch: 0/25, loss_gen: 2.067, loss_dis: 0.498
# ETA: 0.28834, epoch: 137/200, batch: 10/25, loss_gen: 2.071, loss_dis: 0.499
# ETA: 0.28929, epoch: 137/200, batch: 20/25, loss_gen: 2.071, loss_dis: 0.498
# ETA: 7.56720
#
# ETA: 0.28638, epoch: 138/200, batch: 0/25, loss_gen: 2.071, loss_dis: 0.498
# ETA: 0.28657, epoch: 138/200, batch: 10/25, loss_gen: 2.072, loss_dis: 0.497
# ETA: 0.28783, epoch: 138/200, batch: 20/25, loss_gen: 2.072, loss_dis: 0.497
# ETA: 7.56691
#
# ETA: 0.28765, epoch: 139/200, batch: 0/25, loss_gen: 2.073, loss_dis: 0.496
# ETA: 0.28628, epoch: 139/200, batch: 10/25, loss_gen: 2.073, loss_dis: 0.496
# ETA: 0.28454, epoch: 139/200, batch: 20/25, loss_gen: 2.073, loss_dis: 0.495
# ETA: 7.54438
#
# ETA: 0.28316, epoch: 140/200, batch: 0/25, loss_gen: 2.072, loss_dis: 0.495
# ETA: 0.28750, epoch: 140/200, batch: 10/25, loss_gen: 2.071, loss_dis: 0.496
# ETA: 0.28605, epoch: 140/200, batch: 20/25, loss_gen: 2.071, loss_dis: 0.496
# ETA: 7.54822
#
# ETA: 0.28185, epoch: 141/200, batch: 0/25, loss_gen: 2.071, loss_dis: 0.496
# ETA: 0.28437, epoch: 141/200, batch: 10/25, loss_gen: 2.072, loss_dis: 0.496
# ETA: 0.28846, epoch: 141/200, batch: 20/25, loss_gen: 2.072, loss_dis: 0.495
# ETA: 7.58016
#
# ETA: 0.28368, epoch: 142/200, batch: 0/25, loss_gen: 2.072, loss_dis: 0.495
# ETA: 0.28840, epoch: 142/200, batch: 10/25, loss_gen: 2.072, loss_dis: 0.495
# ETA: 0.28746, epoch: 142/200, batch: 20/25, loss_gen: 2.073, loss_dis: 0.494
# ETA: 7.55221
#
# ETA: 0.28783, epoch: 143/200, batch: 0/25, loss_gen: 2.074, loss_dis: 0.493
# ETA: 0.28908, epoch: 143/200, batch: 10/25, loss_gen: 2.075, loss_dis: 0.493
# ETA: 0.28843, epoch: 143/200, batch: 20/25, loss_gen: 2.075, loss_dis: 0.492
# ETA: 7.55730
#
# ETA: 0.28799, epoch: 144/200, batch: 0/25, loss_gen: 2.075, loss_dis: 0.491
# ETA: 0.28625, epoch: 144/200, batch: 10/25, loss_gen: 2.074, loss_dis: 0.492
# ETA: 0.28803, epoch: 144/200, batch: 20/25, loss_gen: 2.074, loss_dis: 0.492
# ETA: 7.55138
#
# ETA: 0.29078, epoch: 145/200, batch: 0/25, loss_gen: 2.075, loss_dis: 0.492
# ETA: 0.28820, epoch: 145/200, batch: 10/25, loss_gen: 2.077, loss_dis: 0.491
# ETA: 0.28457, epoch: 145/200, batch: 20/25, loss_gen: 2.079, loss_dis: 0.490
# ETA: 7.55392
#
# ETA: 0.28527, epoch: 146/200, batch: 0/25, loss_gen: 2.079, loss_dis: 0.490
# ETA: 0.28859, epoch: 146/200, batch: 10/25, loss_gen: 2.086, loss_dis: 0.492
# ETA: 0.28664, epoch: 146/200, batch: 20/25, loss_gen: 2.091, loss_dis: 0.493
# ETA: 7.54514
#
# ETA: 0.28866, epoch: 147/200, batch: 0/25, loss_gen: 2.091, loss_dis: 0.494
# ETA: 0.28905, epoch: 147/200, batch: 10/25, loss_gen: 2.091, loss_dis: 0.494
# ETA: 0.28615, epoch: 147/200, batch: 20/25, loss_gen: 2.091, loss_dis: 0.494
# ETA: 7.55427
#
# ETA: 0.28762, epoch: 148/200, batch: 0/25, loss_gen: 2.092, loss_dis: 0.494
# ETA: 0.28684, epoch: 148/200, batch: 10/25, loss_gen: 2.094, loss_dis: 0.493
# ETA: 0.28515, epoch: 148/200, batch: 20/25, loss_gen: 2.095, loss_dis: 0.492
# ETA: 7.54382
#
# ETA: 0.28861, epoch: 149/200, batch: 0/25, loss_gen: 2.096, loss_dis: 0.492
# ETA: 0.28894, epoch: 149/200, batch: 10/25, loss_gen: 2.097, loss_dis: 0.491
# ETA: 0.28505, epoch: 149/200, batch: 20/25, loss_gen: 2.098, loss_dis: 0.491
# ETA: 7.54260
#
# ETA: 0.28249, epoch: 150/200, batch: 0/25, loss_gen: 2.098, loss_dis: 0.490
# ETA: 0.28896, epoch: 150/200, batch: 10/25, loss_gen: 2.098, loss_dis: 0.490
# ETA: 0.29100, epoch: 150/200, batch: 20/25, loss_gen: 2.097, loss_dis: 0.490
# ETA: 7.58449
#
# ETA: 0.28820, epoch: 151/200, batch: 0/25, loss_gen: 2.097, loss_dis: 0.490
# ETA: 0.28524, epoch: 151/200, batch: 10/25, loss_gen: 2.097, loss_dis: 0.490
# ETA: 0.28549, epoch: 151/200, batch: 20/25, loss_gen: 2.098, loss_dis: 0.489
# ETA: 7.57165
#
# ETA: 0.28664, epoch: 152/200, batch: 0/25, loss_gen: 2.099, loss_dis: 0.489
# ETA: 0.28611, epoch: 152/200, batch: 10/25, loss_gen: 2.100, loss_dis: 0.488
# ETA: 0.29078, epoch: 152/200, batch: 20/25, loss_gen: 2.101, loss_dis: 0.487
# ETA: 7.54707
#
# ETA: 0.28534, epoch: 153/200, batch: 0/25, loss_gen: 2.102, loss_dis: 0.487
# ETA: 0.28714, epoch: 153/200, batch: 10/25, loss_gen: 2.103, loss_dis: 0.486
# ETA: 0.28774, epoch: 153/200, batch: 20/25, loss_gen: 2.104, loss_dis: 0.486
# ETA: 7.56308
#
# ETA: 0.28556, epoch: 154/200, batch: 0/25, loss_gen: 2.104, loss_dis: 0.486
# ETA: 0.29160, epoch: 154/200, batch: 10/25, loss_gen: 2.105, loss_dis: 0.485
# ETA: 0.29014, epoch: 154/200, batch: 20/25, loss_gen: 2.107, loss_dis: 0.485
# ETA: 7.57131
#
# ETA: 0.28954, epoch: 155/200, batch: 0/25, loss_gen: 2.107, loss_dis: 0.484
# ETA: 0.28829, epoch: 155/200, batch: 10/25, loss_gen: 2.108, loss_dis: 0.484
# ETA: 0.28818, epoch: 155/200, batch: 20/25, loss_gen: 2.107, loss_dis: 0.484
# ETA: 7.55406
#
# ETA: 0.29039, epoch: 156/200, batch: 0/25, loss_gen: 2.106, loss_dis: 0.484
# ETA: 0.28938, epoch: 156/200, batch: 10/25, loss_gen: 2.106, loss_dis: 0.484
# ETA: 0.28989, epoch: 156/200, batch: 20/25, loss_gen: 2.107, loss_dis: 0.485
# ETA: 7.58402
#
# ETA: 0.28824, epoch: 157/200, batch: 0/25, loss_gen: 2.108, loss_dis: 0.485
# ETA: 0.29004, epoch: 157/200, batch: 10/25, loss_gen: 2.109, loss_dis: 0.485
# ETA: 0.28864, epoch: 157/200, batch: 20/25, loss_gen: 2.109, loss_dis: 0.485
# ETA: 7.53861
#
# ETA: 0.28755, epoch: 158/200, batch: 0/25, loss_gen: 2.110, loss_dis: 0.484
# ETA: 0.28894, epoch: 158/200, batch: 10/25, loss_gen: 2.111, loss_dis: 0.484
# ETA: 0.29063, epoch: 158/200, batch: 20/25, loss_gen: 2.113, loss_dis: 0.484
# ETA: 7.56126
#
# ETA: 0.28847, epoch: 159/200, batch: 0/25, loss_gen: 2.113, loss_dis: 0.484
# ETA: 0.28831, epoch: 159/200, batch: 10/25, loss_gen: 2.114, loss_dis: 0.483
# ETA: 0.28964, epoch: 159/200, batch: 20/25, loss_gen: 2.114, loss_dis: 0.483
# ETA: 7.58730
#
# ETA: 0.28494, epoch: 160/200, batch: 0/25, loss_gen: 2.114, loss_dis: 0.483
# ETA: 0.28804, epoch: 160/200, batch: 10/25, loss_gen: 2.115, loss_dis: 0.483
# ETA: 0.28855, epoch: 160/200, batch: 20/25, loss_gen: 2.115, loss_dis: 0.482
# ETA: 7.55596
#
# ETA: 0.28961, epoch: 161/200, batch: 0/25, loss_gen: 2.115, loss_dis: 0.482
# ETA: 0.28963, epoch: 161/200, batch: 10/25, loss_gen: 2.116, loss_dis: 0.481
# ETA: 0.29233, epoch: 161/200, batch: 20/25, loss_gen: 2.118, loss_dis: 0.481
# ETA: 7.58630
#
# ETA: 0.28551, epoch: 162/200, batch: 0/25, loss_gen: 2.118, loss_dis: 0.481
# ETA: 0.28832, epoch: 162/200, batch: 10/25, loss_gen: 2.119, loss_dis: 0.480
# ETA: 0.28271, epoch: 162/200, batch: 20/25, loss_gen: 2.121, loss_dis: 0.480
# ETA: 7.56648
#
# ETA: 0.28880, epoch: 163/200, batch: 0/25, loss_gen: 2.123, loss_dis: 0.479
# ETA: 0.28735, epoch: 163/200, batch: 10/25, loss_gen: 2.125, loss_dis: 0.478
# ETA: 0.28475, epoch: 163/200, batch: 20/25, loss_gen: 2.126, loss_dis: 0.478
# ETA: 7.57499
#
# ETA: 0.28896, epoch: 164/200, batch: 0/25, loss_gen: 2.127, loss_dis: 0.478
# ETA: 0.28663, epoch: 164/200, batch: 10/25, loss_gen: 2.126, loss_dis: 0.478
# ETA: 0.28995, epoch: 164/200, batch: 20/25, loss_gen: 2.127, loss_dis: 0.479
# ETA: 7.55182
#
# ETA: 0.28507, epoch: 165/200, batch: 0/25, loss_gen: 2.128, loss_dis: 0.479
# ETA: 0.28878, epoch: 165/200, batch: 10/25, loss_gen: 2.130, loss_dis: 0.479
# ETA: 0.28937, epoch: 165/200, batch: 20/25, loss_gen: 2.132, loss_dis: 0.479
# ETA: 7.55500
#
# ETA: 0.28636, epoch: 166/200, batch: 0/25, loss_gen: 2.132, loss_dis: 0.478
# ETA: 0.28829, epoch: 166/200, batch: 10/25, loss_gen: 2.133, loss_dis: 0.478
# ETA: 0.28707, epoch: 166/200, batch: 20/25, loss_gen: 2.132, loss_dis: 0.477
# ETA: 7.54128
#
# ETA: 0.28882, epoch: 167/200, batch: 0/25, loss_gen: 2.132, loss_dis: 0.477
# ETA: 0.28663, epoch: 167/200, batch: 10/25, loss_gen: 2.132, loss_dis: 0.477
# ETA: 0.28279, epoch: 167/200, batch: 20/25, loss_gen: 2.132, loss_dis: 0.477
# ETA: 7.56615
#
# ETA: 0.28758, epoch: 168/200, batch: 0/25, loss_gen: 2.133, loss_dis: 0.477
# ETA: 0.28876, epoch: 168/200, batch: 10/25, loss_gen: 2.136, loss_dis: 0.478
# ETA: 0.28736, epoch: 168/200, batch: 20/25, loss_gen: 2.138, loss_dis: 0.478
# ETA: 7.53682
#
# ETA: 0.28903, epoch: 169/200, batch: 0/25, loss_gen: 2.138, loss_dis: 0.478
# ETA: 0.28890, epoch: 169/200, batch: 10/25, loss_gen: 2.138, loss_dis: 0.478
# ETA: 0.28371, epoch: 169/200, batch: 20/25, loss_gen: 2.139, loss_dis: 0.477
# ETA: 7.57356
#
# ETA: 0.28754, epoch: 170/200, batch: 0/25, loss_gen: 2.139, loss_dis: 0.477
# ETA: 0.28458, epoch: 170/200, batch: 10/25, loss_gen: 2.139, loss_dis: 0.477
# ETA: 0.28776, epoch: 170/200, batch: 20/25, loss_gen: 2.139, loss_dis: 0.477
# ETA: 7.55345
#
# ETA: 0.28672, epoch: 171/200, batch: 0/25, loss_gen: 2.139, loss_dis: 0.477
# ETA: 0.28826, epoch: 171/200, batch: 10/25, loss_gen: 2.140, loss_dis: 0.477
# ETA: 0.28685, epoch: 171/200, batch: 20/25, loss_gen: 2.141, loss_dis: 0.476
# ETA: 7.55066
#
# ETA: 0.28988, epoch: 172/200, batch: 0/25, loss_gen: 2.142, loss_dis: 0.476
# ETA: 0.29094, epoch: 172/200, batch: 10/25, loss_gen: 2.143, loss_dis: 0.476
# ETA: 0.28669, epoch: 172/200, batch: 20/25, loss_gen: 2.144, loss_dis: 0.475
# ETA: 7.57728
#
# ETA: 0.28748, epoch: 173/200, batch: 0/25, loss_gen: 2.144, loss_dis: 0.475
# ETA: 0.28983, epoch: 173/200, batch: 10/25, loss_gen: 2.149, loss_dis: 0.476
# ETA: 0.28872, epoch: 173/200, batch: 20/25, loss_gen: 2.153, loss_dis: 0.477
# ETA: 7.58769
#
# ETA: 0.28532, epoch: 174/200, batch: 0/25, loss_gen: 2.155, loss_dis: 0.478
# ETA: 0.28950, epoch: 174/200, batch: 10/25, loss_gen: 2.155, loss_dis: 0.478
# ETA: 0.28867, epoch: 174/200, batch: 20/25, loss_gen: 2.154, loss_dis: 0.478
# ETA: 7.54678
#
# ETA: 0.28659, epoch: 175/200, batch: 0/25, loss_gen: 2.154, loss_dis: 0.478
# ETA: 0.28696, epoch: 175/200, batch: 10/25, loss_gen: 2.155, loss_dis: 0.477
# ETA: 0.28829, epoch: 175/200, batch: 20/25, loss_gen: 2.155, loss_dis: 0.477
# ETA: 7.53137
#
# ETA: 0.28673, epoch: 176/200, batch: 0/25, loss_gen: 2.155, loss_dis: 0.477
# ETA: 0.28839, epoch: 176/200, batch: 10/25, loss_gen: 2.155, loss_dis: 0.476
# ETA: 0.28862, epoch: 176/200, batch: 20/25, loss_gen: 2.155, loss_dis: 0.476
# ETA: 7.54181
#
# ETA: 0.28742, epoch: 177/200, batch: 0/25, loss_gen: 2.156, loss_dis: 0.475
# ETA: 0.28843, epoch: 177/200, batch: 10/25, loss_gen: 2.156, loss_dis: 0.475
# ETA: 0.28880, epoch: 177/200, batch: 20/25, loss_gen: 2.158, loss_dis: 0.475
# ETA: 7.56095
#
# ETA: 0.28656, epoch: 178/200, batch: 0/25, loss_gen: 2.159, loss_dis: 0.475
# ETA: 0.28742, epoch: 178/200, batch: 10/25, loss_gen: 2.172, loss_dis: 0.479
# ETA: 0.29118, epoch: 178/200, batch: 20/25, loss_gen: 2.177, loss_dis: 0.481
# ETA: 7.57215
#
# ETA: 0.28728, epoch: 179/200, batch: 0/25, loss_gen: 2.177, loss_dis: 0.481
# ETA: 0.28901, epoch: 179/200, batch: 10/25, loss_gen: 2.176, loss_dis: 0.480
# ETA: 0.28746, epoch: 179/200, batch: 20/25, loss_gen: 2.176, loss_dis: 0.480
# ETA: 7.56569
#
# ETA: 0.28967, epoch: 180/200, batch: 0/25, loss_gen: 2.177, loss_dis: 0.480
# ETA: 0.28823, epoch: 180/200, batch: 10/25, loss_gen: 2.178, loss_dis: 0.479
# ETA: 0.28793, epoch: 180/200, batch: 20/25, loss_gen: 2.179, loss_dis: 0.478
# ETA: 7.56200
#
# ETA: 0.28503, epoch: 181/200, batch: 0/25, loss_gen: 2.180, loss_dis: 0.478
# ETA: 0.28680, epoch: 181/200, batch: 10/25, loss_gen: 2.180, loss_dis: 0.477
# ETA: 0.29209, epoch: 181/200, batch: 20/25, loss_gen: 2.180, loss_dis: 0.478
# ETA: 7.59003
#
# ETA: 0.28757, epoch: 182/200, batch: 0/25, loss_gen: 2.179, loss_dis: 0.478
# ETA: 0.28936, epoch: 182/200, batch: 10/25, loss_gen: 2.178, loss_dis: 0.478
# ETA: 0.28728, epoch: 182/200, batch: 20/25, loss_gen: 2.178, loss_dis: 0.478
# ETA: 7.55642
#
# ETA: 0.28553, epoch: 183/200, batch: 0/25, loss_gen: 2.177, loss_dis: 0.478
# ETA: 0.28751, epoch: 183/200, batch: 10/25, loss_gen: 2.177, loss_dis: 0.478
# ETA: 0.28945, epoch: 183/200, batch: 20/25, loss_gen: 2.178, loss_dis: 0.478
# ETA: 7.54125
#
# ETA: 0.28684, epoch: 184/200, batch: 0/25, loss_gen: 2.177, loss_dis: 0.478
# ETA: 0.28870, epoch: 184/200, batch: 10/25, loss_gen: 2.178, loss_dis: 0.477
# ETA: 0.28965, epoch: 184/200, batch: 20/25, loss_gen: 2.179, loss_dis: 0.477
# ETA: 7.56280
#
# ETA: 0.28834, epoch: 185/200, batch: 0/25, loss_gen: 2.179, loss_dis: 0.477
# ETA: 0.28641, epoch: 185/200, batch: 10/25, loss_gen: 2.179, loss_dis: 0.477
# ETA: 0.28752, epoch: 185/200, batch: 20/25, loss_gen: 2.179, loss_dis: 0.477
# ETA: 7.55850
#
# ETA: 0.28503, epoch: 186/200, batch: 0/25, loss_gen: 2.179, loss_dis: 0.476
# ETA: 0.28775, epoch: 186/200, batch: 10/25, loss_gen: 2.179, loss_dis: 0.476
# ETA: 0.28405, epoch: 186/200, batch: 20/25, loss_gen: 2.179, loss_dis: 0.476
# ETA: 7.53699
#
# ETA: 0.28710, epoch: 187/200, batch: 0/25, loss_gen: 2.179, loss_dis: 0.476
# ETA: 0.28752, epoch: 187/200, batch: 10/25, loss_gen: 2.180, loss_dis: 0.476
# ETA: 0.28626, epoch: 187/200, batch: 20/25, loss_gen: 2.180, loss_dis: 0.475
# ETA: 7.56076
#
# ETA: 0.28901, epoch: 188/200, batch: 0/25, loss_gen: 2.180, loss_dis: 0.475
# ETA: 0.28927, epoch: 188/200, batch: 10/25, loss_gen: 2.180, loss_dis: 0.474
# ETA: 0.29029, epoch: 188/200, batch: 20/25, loss_gen: 2.179, loss_dis: 0.474
# ETA: 7.55545
#
# ETA: 0.28977, epoch: 189/200, batch: 0/25, loss_gen: 2.178, loss_dis: 0.474
# ETA: 0.28905, epoch: 189/200, batch: 10/25, loss_gen: 2.177, loss_dis: 0.473
# ETA: 0.28379, epoch: 189/200, batch: 20/25, loss_gen: 2.178, loss_dis: 0.473
# ETA: 7.55516
#
# ETA: 0.28707, epoch: 190/200, batch: 0/25, loss_gen: 2.178, loss_dis: 0.473
# ETA: 0.29091, epoch: 190/200, batch: 10/25, loss_gen: 2.178, loss_dis: 0.472
# ETA: 0.28294, epoch: 190/200, batch: 20/25, loss_gen: 2.180, loss_dis: 0.472
# ETA: 7.55525
#
# ETA: 0.28891, epoch: 191/200, batch: 0/25, loss_gen: 2.182, loss_dis: 0.472
# ETA: 0.28601, epoch: 191/200, batch: 10/25, loss_gen: 2.185, loss_dis: 0.471
# ETA: 0.28850, epoch: 191/200, batch: 20/25, loss_gen: 2.187, loss_dis: 0.471
# ETA: 7.57497
#
# ETA: 0.28758, epoch: 192/200, batch: 0/25, loss_gen: 2.190, loss_dis: 0.471
# ETA: 0.28919, epoch: 192/200, batch: 10/25, loss_gen: 2.200, loss_dis: 0.472
# ETA: 0.28965, epoch: 192/200, batch: 20/25, loss_gen: 2.204, loss_dis: 0.472
# ETA: 7.58181
#
# ETA: 0.29039, epoch: 193/200, batch: 0/25, loss_gen: 2.208, loss_dis: 0.473
# ETA: 0.28984, epoch: 193/200, batch: 10/25, loss_gen: 2.211, loss_dis: 0.474
# ETA: 0.28750, epoch: 193/200, batch: 20/25, loss_gen: 2.211, loss_dis: 0.474
# ETA: 7.56822
#
# ETA: 0.28402, epoch: 194/200, batch: 0/25, loss_gen: 2.212, loss_dis: 0.475
# ETA: 0.28893, epoch: 194/200, batch: 10/25, loss_gen: 2.212, loss_dis: 0.475
# ETA: 0.28705, epoch: 194/200, batch: 20/25, loss_gen: 2.212, loss_dis: 0.475
# ETA: 7.55056
#
# ETA: 0.29097, epoch: 195/200, batch: 0/25, loss_gen: 2.212, loss_dis: 0.475
# ETA: 0.29091, epoch: 195/200, batch: 10/25, loss_gen: 2.213, loss_dis: 0.474
# ETA: 0.28869, epoch: 195/200, batch: 20/25, loss_gen: 2.214, loss_dis: 0.473
# ETA: 7.61586
#
# ETA: 0.28965, epoch: 196/200, batch: 0/25, loss_gen: 2.214, loss_dis: 0.473
# ETA: 0.29030, epoch: 196/200, batch: 10/25, loss_gen: 2.215, loss_dis: 0.473
# ETA: 0.28794, epoch: 196/200, batch: 20/25, loss_gen: 2.215, loss_dis: 0.473
# ETA: 7.59395
#
# ETA: 0.28906, epoch: 197/200, batch: 0/25, loss_gen: 2.216, loss_dis: 0.473
# ETA: 0.28748, epoch: 197/200, batch: 10/25, loss_gen: 2.217, loss_dis: 0.472
# ETA: 0.28960, epoch: 197/200, batch: 20/25, loss_gen: 2.218, loss_dis: 0.471
# ETA: 7.61861
#
# ETA: 0.28853, epoch: 198/200, batch: 0/25, loss_gen: 2.218, loss_dis: 0.471
# ETA: 0.28944, epoch: 198/200, batch: 10/25, loss_gen: 2.218, loss_dis: 0.471
# ETA: 0.28855, epoch: 198/200, batch: 20/25, loss_gen: 2.218, loss_dis: 0.471
# ETA: 7.58594
#
# ETA: 0.28596, epoch: 199/200, batch: 0/25, loss_gen: 2.220, loss_dis: 0.471
# ETA: 0.29111, epoch: 199/200, batch: 10/25, loss_gen: 2.220, loss_dis: 0.472
# ETA: 0.28774, epoch: 199/200, batch: 20/25, loss_gen: 2.219, loss_dis: 0.473
# ETA: 7.56594
#
# ETA: 0.28537, epoch: 200/200, batch: 0/25, loss_gen: 2.219, loss_dis: 0.473
# ETA: 0.28678, epoch: 200/200, batch: 10/25, loss_gen: 2.219, loss_dis: 0.472
# ETA: 0.28578, epoch: 200/200, batch: 20/25, loss_gen: 2.218, loss_dis: 0.472
# ETA: 7.55882

# %% [markdown]
# ### Plot the losses

# %%
def running_mean(data, periods=10):
    # from https://github.com/artemsavkin/latent3d/blob/master/pcl_latent3d_shapenet.ipynb
    weights = np.ones(periods) / periods
    return np.convolve(data, weights, mode='valid')

rm_losses_gen = running_mean(np.asarray(losses_gen))
rm_losses_dis = running_mean(np.asarray(losses_dis))


plt.plot(range(0, len(rm_losses_gen)), rm_losses_gen, 'r-', label='Generator')
plt.plot(range(0, len(rm_losses_dis)), rm_losses_dis, 'b-', label='Discriminator')
plt.gca().patch.set_alpha(0)
plt.title('r-GAN Losses')
plt.legend()
plt.show()

# %% [markdown]
# ## Save the model

# %%
torch.save(
    {
      'raw_gan_generator': raw_gan_gen.state_dict(),
      'raw_gan_discriminator': raw_gan_dis.state_dict()
    },
    shape_name+'_raw_gan.tar'
    )

# %%
loaded_model = torch.load(shape_name+'_raw_gan.tar', map_location=device)
loaded_model['raw_gan_generator']
# Out:
# OrderedDict([('model.0.weight',
#               tensor([[ 0.1021,  0.0611,  0.0606,  ..., -0.0531, -0.1167,  0.0832],
#                       [-0.0972,  0.0351,  0.0234,  ...,  0.0444,  0.0459,  0.0252],
#                       [-0.0270, -0.0571,  0.0263,  ...,  0.0140, -0.1044, -0.0842],
#                       ...,
#                       [ 0.1203,  0.1078,  0.1381,  ..., -0.0488, -0.0223,  0.1223],
#                       [ 0.0002,  0.0046,  0.0866,  ..., -0.0365, -0.0374,  0.0800],
#                       [ 0.0404,  0.0739,  0.0197,  ...,  0.0551, -0.1348,  0.0574]],
#                      device='cuda:0')),
#              ('model.0.bias',
#               tensor([-0.0486, -0.0970, -0.0136, -0.1104,  0.0207, -0.0230, -0.0793, -0.0199,
#                       -0.0181, -0.0604, -0.0480, -0.0940, -0.0841, -0.0642, -0.0818, -0.0687,
#                       -0.0029, -0.0402, -0.0769, -0.0614, -0.0490, -0.0465, -0.1054, -0.0765,
#                       -0.0543, -0.0112, -0.0358, -0.0426, -0.0609, -0.0782, -0.0993, -0.0975,
#                       -0.0947, -0.0489, -0.0382, -0.0915, -0.0747, -0.0521, -0.0580, -0.1142,
#                       -0.0429, -0.0585, -0.0387, -0.0955, -0.0810, -0.0880, -0.0832, -0.0795,
#                       -0.0864, -0.0691, -0.0484, -0.0274, -0.0900, -0.0909, -0.0832, -0.0475,
#                       -0.0130, -0.0475, -0.0662, -0.0212, -0.0864, -0.0333, -0.0506,  0.0182],
#                      device='cuda:0')),
#              ('model.2.weight',
#               tensor([[-0.0467, -0.0513, -0.0248,  ...,  0.0453, -0.0309,  0.1382],
#                       [ 0.0105,  0.0681, -0.1885,  ...,  0.1032,  0.0439,  0.0180],
#                       [ 0.0626, -0.0352,  0.0556,  ..., -0.0465, -0.0523, -0.0908],
#                       ...,
#                       [ 0.0168,  0.0419,  0.0680,  ...,  0.0307,  0.0876, -0.1625],
#                       [ 0.0480,  0.0448,  0.0890,  ..., -0.0876,  0.0964, -0.0172],
#                       [ 0.0916,  0.0294, -0.0292,  ..., -0.0118,  0.1026, -0.1030]],
#                      device='cuda:0')),
#              ('model.2.bias',
#               tensor([-0.0161, -0.0275, -0.0261, -0.0023, -0.0050, -0.0192, -0.0197, -0.0396,
#                        0.0159,  0.0352, -0.0311, -0.0253,  0.0046,  0.0191, -0.0398,  0.0078,
#                        0.0017, -0.0284, -0.0473, -0.0214, -0.0104, -0.0159,  0.0019, -0.0363,
#                       -0.0221, -0.0161, -0.0361, -0.0039,  0.0170, -0.0377, -0.0200,  0.0094,
#                       -0.0252, -0.0151, -0.0451, -0.0324, -0.0324, -0.0215, -0.0290, -0.0187,
#                       -0.0440, -0.0093,  0.0066, -0.0095, -0.0189,  0.0040, -0.0235,  0.0044,
#                        0.0082,  0.0004, -0.0134, -0.0226, -0.0353, -0.0402,  0.0456,  0.0515,
#                       -0.0359, -0.0118, -0.0328, -0.0017,  0.0164,  0.0176,  0.0142, -0.0442,
#                        0.0106, -0.0286, -0.0004,  0.0022, -0.0402, -0.0235,  0.0178, -0.0425,
#                       -0.0183, -0.0338,  0.0187,  0.0020, -0.0309, -0.0360, -0.0323,  0.0054,
#                        0.0204, -0.0357, -0.0329, -0.0168, -0.0048, -0.0189, -0.0121,  0.0136,
#                       -0.0235,  0.0326, -0.0343, -0.0101, -0.0053,  0.0029, -0.0113,  0.0319,
#                       -0.0358, -0.0020, -0.0200,  0.0098, -0.0426, -0.0244,  0.0068, -0.0368,
#                       -0.0046, -0.0252,  0.0005, -0.0255, -0.0191,  0.0330, -0.0214,  0.0059,
#                        0.0147, -0.0257, -0.0258, -0.0177, -0.0245, -0.0232,  0.0109, -0.0137,
#                        0.0076, -0.0261,  0.0227,  0.0072, -0.0333, -0.0119, -0.0216,  0.0259],
#                      device='cuda:0')),
#              ('model.4.weight',
#               tensor([[-0.0012, -0.0397,  0.0451,  ..., -0.0320, -0.0435, -0.0323],
#                       [ 0.0484, -0.0347, -0.0312,  ...,  0.0596, -0.0036, -0.0070],
#                       [ 0.0616, -0.0849, -0.0323,  ..., -0.0181,  0.0211, -0.0304],
#                       ...,
#                       [-0.0386, -0.0795,  0.0607,  ..., -0.0147, -0.0722, -0.0692],
#                       [-0.0933,  0.0126, -0.0516,  ..., -0.0739, -0.0149,  0.0522],
#                       [ 0.0192, -0.0197,  0.0160,  ...,  0.0465, -0.0833, -0.0366]],
#                      device='cuda:0')),
#              ('model.4.bias',
#               tensor([ 4.9902e-03, -1.6260e-03, -1.0777e-03, -1.1673e-02, -1.5460e-02,
#                       -1.6787e-02, -2.8972e-03, -1.6955e-02,  5.5190e-03,  9.8399e-03,
#                        3.6408e-03, -6.2984e-03, -1.2333e-02,  3.8942e-03,  6.9942e-03,
#                       -2.9510e-03, -1.3405e-02,  2.2915e-03, -8.8749e-03,  1.8827e-03,
#                       -1.9771e-03, -3.2963e-03, -1.1149e-03,  4.1783e-03, -6.8295e-03,
#                       -4.1875e-03,  1.7358e-02, -8.0010e-03, -7.1412e-03, -3.3028e-03,
#                        9.6325e-03, -6.1699e-03, -1.1871e-02, -3.1246e-02, -7.1352e-03,
#                       -1.7133e-02, -6.6746e-03, -8.8717e-03, -6.9479e-03, -3.1515e-03,
#                       -3.9945e-03,  2.2140e-03, -1.0762e-03, -1.0430e-02, -6.5110e-04,
#                       -3.0422e-03, -1.0736e-02, -1.1750e-02, -5.9451e-03, -1.3030e-02,
#                       -6.2059e-03, -1.6803e-02,  1.1764e-02, -3.5258e-03, -1.2029e-02,
#                       -1.7363e-03,  2.9269e-03, -7.0775e-04, -1.2145e-02, -7.8785e-03,
#                        1.4528e-03,  3.3432e-03, -4.0608e-03, -1.4175e-02, -5.5200e-03,
#                        1.0009e-02, -6.6420e-03,  8.2083e-03, -1.1942e-02, -1.5413e-02,
#                       -3.4193e-05, -1.4674e-02, -1.7642e-02, -2.0148e-02,  1.7857e-02,
#                       -1.0742e-02,  6.0784e-03, -8.2898e-03, -9.4946e-03, -4.1974e-03,
#                        4.9583e-03, -2.3990e-02, -2.6937e-03,  5.2216e-03, -1.0860e-02,
#                        5.3187e-03, -2.9886e-02, -5.4957e-03, -1.7448e-02,  1.4851e-03,
#                       -1.1032e-02, -1.1189e-02,  8.2586e-03, -1.1539e-02, -4.0018e-03,
#                       -1.5840e-02, -1.0197e-02,  2.0958e-02, -8.6571e-03,  1.6098e-02,
#                       -1.5736e-02, -7.7881e-03, -2.4453e-02,  1.4846e-02, -3.7268e-03,
#                       -9.9028e-03, -1.5292e-03, -3.9389e-03,  8.7948e-04,  8.2926e-03,
#                        6.9615e-04, -9.8352e-03, -9.7708e-03, -2.0107e-02, -9.2392e-03,
#                       -1.3538e-02,  1.3747e-02,  7.7706e-04, -6.2514e-03,  4.4951e-03,
#                       -1.8671e-03, -6.0671e-03, -3.5204e-03, -1.7357e-02,  1.9364e-03,
#                       -3.9996e-03, -2.3556e-03, -1.5325e-02,  9.8840e-04, -1.3470e-02,
#                        6.8494e-03,  1.1628e-02, -3.9108e-03, -3.9854e-04,  8.2205e-03,
#                        2.8277e-03, -4.6399e-04,  1.2652e-02, -2.5937e-03, -1.3901e-02,
#                        5.5665e-03,  9.3740e-03, -7.0156e-03, -5.2711e-04,  1.3278e-03,
#                       -1.5812e-02,  4.4535e-03,  5.4682e-03, -1.5704e-02, -6.8567e-03,
#                        1.1378e-03,  2.2931e-02,  6.8356e-03, -4.1000e-03,  1.0172e-02,
#                       -1.4019e-02, -2.6292e-03, -8.7070e-03,  9.8964e-03, -4.6074e-03,
#                        2.1272e-02, -7.8550e-04, -1.5736e-02, -2.4998e-05,  3.2487e-03,
#                       -2.3436e-03,  8.3271e-04, -2.6692e-03, -1.1581e-02, -1.0884e-02,
#                        3.1192e-02, -1.1202e-02, -1.7481e-03, -1.5244e-02, -1.6614e-02,
#                       -5.4976e-03, -1.5317e-02, -8.4379e-03, -5.2223e-03, -1.4475e-02,
#                       -5.1031e-03, -3.1687e-03, -9.7186e-03, -1.9593e-03,  4.8269e-03,
#                       -6.8171e-04, -8.7375e-03, -1.6800e-02,  8.2649e-03, -1.1610e-02,
#                       -1.5485e-02,  1.4632e-02, -1.1323e-02,  2.7157e-03, -2.3812e-03,
#                       -5.5428e-03, -7.7150e-03,  9.1710e-03,  1.9496e-03, -1.3881e-02,
#                        7.0576e-03, -1.0312e-02,  2.4911e-03,  8.8595e-03, -6.1734e-03,
#                       -1.1132e-02,  1.0634e-02,  5.1154e-03, -3.2369e-03, -1.8604e-02,
#                       -4.3192e-03,  2.1244e-03,  5.6651e-03, -7.6121e-03, -1.3222e-02,
#                       -2.2271e-02, -2.3303e-03,  2.8868e-04, -1.1200e-02, -1.3795e-02,
#                       -3.2879e-02, -1.5173e-02, -7.6040e-03, -1.0940e-02, -1.0817e-02,
#                       -5.5345e-03, -1.9653e-02, -1.3179e-03, -2.7832e-02,  2.4155e-03,
#                       -1.4376e-02, -9.3075e-03, -1.0325e-02,  1.8028e-02, -5.4511e-03,
#                        1.1835e-02, -1.0565e-04, -1.4598e-02, -1.2205e-02, -3.7868e-03,
#                        2.4865e-02, -3.2223e-03, -4.5790e-03, -5.0148e-03, -6.0227e-03,
#                        2.4209e-02,  3.1418e-03, -1.2998e-03, -7.1378e-03, -1.5540e-02,
#                       -9.8379e-03,  2.1397e-02,  3.9709e-03, -1.6585e-02, -9.0484e-03,
#                        9.9229e-03, -8.7985e-03, -7.3321e-03, -7.2310e-03, -1.0202e-02,
#                       -9.2117e-03,  2.0565e-03, -4.5728e-03, -4.2240e-04,  3.7622e-03,
#                       -5.0881e-03, -5.2204e-03, -9.2577e-03, -1.5299e-02, -8.9104e-04,
#                       -1.4722e-02, -3.4637e-03, -7.3432e-03, -8.2896e-03,  7.2171e-03,
#                       -4.9854e-03, -6.8915e-03, -1.1958e-02, -1.4239e-02,  3.7824e-03,
#                        1.9333e-03, -9.8517e-03, -1.1664e-02, -2.2957e-04, -2.0422e-02,
#                       -2.0417e-02,  4.9068e-03, -1.3732e-02, -1.4898e-03,  5.3008e-03,
#                       -1.5418e-02, -2.2346e-03, -1.2611e-02, -4.6322e-03, -1.3529e-02,
#                       -1.8920e-02,  3.6293e-03, -2.1772e-02, -1.0882e-02,  2.7236e-03,
#                        1.0942e-04, -4.1032e-03, -1.0901e-02, -1.5855e-02, -1.5000e-02,
#                        4.8553e-03,  9.1576e-03, -1.0017e-02, -1.0490e-02, -9.3179e-03,
#                        1.7487e-02,  1.4226e-02, -1.3241e-02, -1.1668e-02,  2.8840e-03,
#                       -2.0911e-03, -3.2612e-04,  4.4640e-03, -4.1824e-03, -3.4826e-03,
#                       -2.0411e-02, -1.2628e-03,  5.1605e-03, -6.3231e-03,  2.7128e-03,
#                       -5.8025e-03, -8.5070e-03,  1.0036e-03, -2.2084e-02, -6.2841e-03,
#                        5.3080e-03, -3.8324e-03, -3.3317e-03, -7.2232e-03,  8.8483e-03,
#                       -1.3874e-02,  1.3050e-03, -9.7647e-03, -4.1082e-03, -1.4153e-02,
#                       -2.7818e-03,  9.8855e-04,  1.3310e-02, -8.3652e-03,  1.0186e-04,
#                        3.5672e-03, -1.4260e-02, -1.8006e-02, -3.0031e-03, -1.1446e-02,
#                       -7.5939e-03, -8.4202e-05, -1.3348e-02,  1.0493e-02,  3.3005e-03,
#                       -2.3053e-02, -1.8090e-02, -1.0055e-02, -2.2727e-03,  5.8896e-06,
#                        1.1242e-02, -2.0394e-03,  2.0965e-02,  1.2744e-03, -1.7431e-03,
#                       -1.6960e-02, -4.9620e-03,  1.2783e-02, -1.2037e-02, -2.0726e-02,
#                        7.6458e-03, -3.0727e-03,  7.0427e-03,  1.1808e-02, -5.0361e-03,
#                        3.7299e-03,  3.3578e-03, -4.4577e-03, -2.3837e-03, -1.1454e-02,
#                       -1.3425e-02, -1.8887e-02, -6.5218e-03, -1.9287e-02, -8.6935e-03,
#                       -3.3238e-03, -2.1391e-03,  9.1575e-03,  1.5499e-02, -3.9205e-03,
#                       -8.0850e-03, -1.3586e-02, -1.3460e-02,  1.1252e-04, -9.6370e-04,
#                       -1.1338e-02, -9.1298e-03,  2.9768e-03,  1.1622e-03,  1.5137e-02,
#                       -6.5920e-03, -3.4404e-03,  2.9730e-03, -3.2334e-03, -2.1955e-02,
#                        6.1548e-06,  6.1627e-03,  8.4976e-03,  4.6000e-03, -6.8035e-03,
#                       -2.0375e-02, -1.2778e-03,  1.0538e-02, -9.6209e-03,  1.1259e-02,
#                        7.3410e-03, -1.0153e-02, -1.6761e-03, -8.0432e-03,  8.7912e-03,
#                        5.3427e-03,  4.1828e-03, -2.1784e-03, -1.1990e-02, -1.0417e-02,
#                        4.5792e-03, -1.6754e-02, -2.6973e-03, -1.1014e-04,  7.4715e-03,
#                       -1.5296e-02, -1.1053e-02,  2.3853e-02, -7.5139e-03, -1.4455e-03,
#                       -1.0642e-02, -1.7438e-02, -6.1418e-03, -1.2669e-02, -8.9025e-03,
#                       -1.2608e-02, -2.4853e-03, -5.0773e-03,  2.1980e-03, -9.5022e-03,
#                       -1.8859e-02,  1.2444e-02,  3.9894e-03, -8.7841e-03,  9.3456e-03,
#                       -1.2902e-02,  7.8093e-03, -1.8280e-02, -8.9839e-06,  4.1185e-04,
#                       -1.0238e-02, -1.1093e-02, -1.1530e-02, -6.5217e-03,  2.5792e-03,
#                        1.2973e-02, -1.8256e-02, -8.8407e-03, -1.5967e-02,  3.1042e-03,
#                       -9.0682e-03,  5.8322e-03, -2.2862e-02,  4.9899e-03,  1.3030e-03,
#                       -1.1487e-02,  5.7249e-03, -8.7522e-04, -9.7641e-04, -8.6603e-03,
#                        4.9640e-03, -3.9837e-03,  6.8999e-03, -1.3104e-02,  2.2240e-03,
#                        6.9585e-03,  9.7877e-04,  4.9363e-03, -8.8161e-03, -1.0714e-02,
#                       -1.3389e-02,  1.5063e-03, -1.3024e-02, -1.8485e-03, -1.0538e-02,
#                       -4.8991e-04,  1.4705e-03, -1.8908e-02, -4.6732e-03, -6.6954e-03,
#                        1.0074e-05, -8.0789e-03, -2.3354e-02,  2.5975e-03,  5.3511e-03,
#                       -1.4911e-03, -8.8788e-03, -2.6013e-02, -1.1542e-02, -3.8412e-03,
#                       -1.0121e-02, -1.0365e-02, -6.9887e-03, -3.1557e-03, -1.9909e-02,
#                        2.0844e-03, -6.8904e-03], device='cuda:0')),
#              ('model.6.weight',
#               tensor([[ 0.0490, -0.0264,  0.0053,  ..., -0.0392,  0.0345,  0.0514],
#                       [-0.0263,  0.0175,  0.0206,  ..., -0.0483, -0.0028, -0.0112],
#                       [ 0.0002,  0.0365,  0.0010,  ..., -0.0168,  0.0065, -0.0238],
#                       ...,
#                       [-0.0416, -0.0017,  0.0129,  ..., -0.0375,  0.0357,  0.0016],
#                       [-0.0076, -0.0376,  0.0124,  ..., -0.0213,  0.0461,  0.0592],
#                       [ 0.0247,  0.0482,  0.0198,  ..., -0.0332, -0.0357,  0.0525]],
#                      device='cuda:0')),
#              ('model.6.bias',
#               tensor([-0.0074, -0.0047, -0.0074,  ..., -0.0119, -0.0035,  0.0016],
#                      device='cuda:0')),
#              ('model.8.weight',
#               tensor([[ 1.1708e-02,  4.5066e-03,  6.6022e-03,  ...,  3.0376e-02,
#                         1.1626e-02, -1.2971e-02],
#                       [-2.3163e-02,  2.7171e-02, -1.6068e-03,  ..., -2.5076e-02,
#                        -2.5919e-02,  8.9543e-03],
#                       [-1.2491e-03,  3.2624e-02,  6.3913e-03,  ...,  8.1812e-05,
#                        -2.2306e-02, -3.0826e-03],
#                       ...,
#                       [-2.6276e-03, -2.4288e-02, -9.2666e-03,  ...,  2.9856e-02,
#                        -1.8319e-02,  6.6682e-04],
#                       [ 1.2428e-03, -5.9570e-03, -1.6873e-02,  ...,  6.1320e-03,
#                        -1.5633e-02, -2.1517e-02],
#                       [-1.8240e-02, -1.6913e-02,  5.9753e-03,  ..., -1.2923e-02,
#                        -2.1296e-02, -2.2891e-02]], device='cuda:0')),
#              ('model.8.bias',
#               tensor([ 0.0018, -0.0051,  0.0067,  ..., -0.0005, -0.0022,  0.0007],
#                      device='cuda:0'))])

# %% [markdown]
# ### Generate samples

# %%
batch_idx, batch_data = next(enumerate(dataloader))
x = batch_data.pos.reshape(batch_size, n_points, 3).transpose(2, 1).cpu().detach().numpy()

# sample the noise vector:
z = torch.Tensor(batch_size, raw_gan_gen_input_dim).normal_(mu, sigma).to(device)
gen_samples = raw_gan_gen(z).cpu().detach().numpy()

print(x.shape)
print(gen_samples.shape)


for i in range(batch_size):
  visualize_points(gen_samples[i].transpose(1,0), is_shapenet=True)
  # visualize_real_and_generated_samples([x[i].transpose(1,0), gen_samples[i].transpose(1,0)], is_shapenet=True)
# Out:
# (50, 3, 2048)
# (50, 3, 2048)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
